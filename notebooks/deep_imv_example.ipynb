# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.optim import AdamW

from diomics.models.fc_imv import FC_Marginal, JointVAE

import numpy as np
import pandas as pd
import copy

from sklearn.metrics import roc_curve, auc, confusion_matrix

import matplotlib.pyplot as plt

# %% [markdown]
# ## Example of a forward pass on fake data

# %%
# two arbitrary views, one with 1000 features, and another with 500 features
marg_model1 = FC_Marginal(input_size=1000, hidden_sizes=[128, 128], z_dim=10, prediction_dim=10)
marg_model2 = FC_Marginal(input_size=500, hidden_sizes=[64, 64], z_dim=10, prediction_dim=10)

# joint model
joint_model = JointVAE(marginal_models=[marg_model1, marg_model2], hidden_dim=128)

# define optimizer
optimizer = AdamW(joint_model.parameters(), lr=1e-3)

# %%
# fake inputs/targets
example_input1 = torch.randn(100, 1000)
example_input2 = torch.randn(100, 500)
example_target = torch.randint(0, 10, (100,))

# %%
# get the predictions and distribution of the joint model, and the predictions and distributions of the marginal models
yhat, poe_dist, yhats, dists = joint_model([example_input1, example_input2])

# %%
# pass the predictions and distributions to the loss function and update parameters
loss = joint_model.loss(example_target, yhat, poe_dist, yhats, dists)
loss.backward()

# %% [markdown]
# ## Example with real data

# %%
proData = pd.read_csv('~/Documents/Data/example_omicsdata/multi-omics-from-share/ICL104_Pep_Prot_Lipid_Metab/ICL104_proteins_luke.csv')
lipData = pd.read_excel("/Volumes/Data_Harmony/DHS_Omics/ICL04/ICL104_lipids_aligned_for_stats.xlsx")
metabData = pd.read_excel("/Volumes/Data_Harmony/DHS_Omics/ICL04/OMICS_ICL104_Metabolomics_YMK.xlsx")
metabData = metabData.drop(columns=['KEGG', 'CAS', 'PubChem'])

fmeta = pd.read_csv('~/Documents/Data/example_omicsdata/multi-omics-from-share/ICL104_Pep_Prot_Lipid_Metab/ICL104_fmeta.csv')

# %%
# significant biomolecules
pro_anova = pd.read_csv("./data/anova_results/pep/anova_results.csv")
lip_pos_anova = pd.read_csv("./data/anova_results/lip_pos/anova_results.csv")
# lip_neg_anova = pd.read_csv("./data/anova_results/lip_neg/anova_results.csv")
metab_anova = pd.read_csv("./data/anova_results/metab/anova_results.csv")

# %%
# some samples missing from some datasets.
lipData.shape, metabData.shape, proData.shape|
# Out:
# ((250, 61), (138, 61), (2853, 61))

# %%
# make the id column in the data the index
lipData = lipData.set_index('Name')
metabData = metabData.set_index('Metabolite')
proData = proData.set_index('Protein')

# replace zeros with NA
lipData[lipData == 0] = np.nan
metabData[metabData == 0] = np.nan

# log2 transform the data and column-wise median center
lipData = np.log2(lipData)
metabData = np.log2(metabData)
# proData = np.log2(proData) # already log 2

lipData = lipData - lipData.median(axis=0)
metabData = metabData - metabData.median(axis=0)
proData = proData - proData.median(axis=0)

# [0, 1] normalize all the data
lipData = (lipData - np.min(lipData)) / (np.max(lipData) - np.min(lipData))
metabData = (metabData - np.min(metabData)) / (np.max(metabData) - np.min(metabData))
proData = (proData - np.min(proData)) / (np.max(proData) - np.min(proData))

# %%
# columns are nicely aligned
y = pd.Series(['Cal' if 'Cal04' in el else 'Mock' for el in lipData.columns])

# %%
# drop indices with all null values
lip_inds = (lipData.isnull() == False).sum(axis = 1) > 0
metab_inds = (metabData.isnull() == False).sum(axis = 1) > 0
pro_inds = (proData.isnull() == False).sum(axis = 1) > 0

lipData = lipData[lip_inds]
metabData = metabData[metab_inds]
proData = proData[pro_inds]

# impute the datasets with the row means
lipData = lipData.apply(lambda row: row.fillna(row.mean()), axis=1)
metabData = metabData.apply(lambda row: row.fillna(row.mean()), axis=1)
proData = proData.apply(lambda row: row.fillna(row.mean()), axis=1)

# %%
lip_pos_anova = lip_pos_anova[lip_pos_anova.Lipid.isin(lipData.index)]
metab_anova = metab_anova[metab_anova.Metabolite.isin(metabData.index)]
pro_anova = pro_anova[pro_anova.Protein.isin(proData.index)]

lip_pos_anova.shape, metab_anova.shape, pro_anova.shape
# Out:
# ((250, 8), (133, 8), (2853, 8))

# %%
# optionally subset the data to only include significant biomolecules
sig_lipids = lip_pos_anova[lip_pos_anova["P_value_A_Cal04_vs_Mock"] < 0.05].Lipid
sig_metabs = metab_anova[metab_anova["P_value_A_Cal04_vs_Mock"] < 0.05].Metabolite
sig_proteins = pro_anova[pro_anova["P_value_A_Cal04_vs_Mock"] < 0.05].Protein

lipData = lipData.loc[sig_lipids]
metabData = metabData.loc[sig_metabs]
proData = proData.loc[sig_proteins]

lipData.shape, metabData.shape, proData.shape
# Out:
# ((118, 60), (25, 60), (416, 60))

# %%
# get the elements in lipData.columns that are in fmeta['SampleID_lipidpos']
# lipData = lipData.loc[:,lipData.columns.isin(fmeta['SampleID_lipidpos'])]
# metabData = metabData.loc[:,metabData.columns.isin(fmeta['SampleID_metab'])]
# proData = proData.loc[:,proData.columns.isin(fmeta['SampleID_proteomics'])]

np.random.seed(1565)
cal_inds = np.random.choice(np.where(y == 'Cal')[0], int(np.sum(y == 'Cal') * 0.2))
mock_inds = np.random.choice(np.where(y == 'Mock')[0], int(np.sum(y == 'Mock') * 0.2))
test_inds = np.concatenate([cal_inds, mock_inds])

train_inds = np.isin(np.arange(y.shape[0]), test_inds) == False

train_lip = lipData.iloc[:,train_inds]
train_pro = proData.iloc[:,train_inds]
train_metab = metabData.iloc[:,train_inds]

test_lip = lipData.iloc[:, test_inds]
test_pro = proData.iloc[:, test_inds]
test_metab = metabData.iloc[:, test_inds]

ytrain = y.iloc[train_inds]
ytest = y.iloc[test_inds]

# %% [markdown]
# ### Construct the Model

# %%
# three view-specific encoders with the appropriate input size:
lip_marg = FC_Marginal(input_size=train_lip.shape[0], hidden_sizes=[128, 128], z_dim=10, prediction_dim=y.nunique())
metab_marg = FC_Marginal(input_size=train_metab.shape[0], hidden_sizes=[64, 64], z_dim=10, prediction_dim=y.nunique())
pro_marg = FC_Marginal(input_size=train_pro.shape[0], hidden_sizes=[256, 128], z_dim=10, prediction_dim=y.nunique())

# joint model
joint_model = JointVAE(marginal_models=[lip_marg, metab_marg, pro_marg], hidden_dim=128)

# define optimizer
optimizer = AdamW(joint_model.parameters(), lr=1e-3)

# %%
# turn data into tensors
lip_tensor = torch.tensor(train_lip.T.values, dtype=torch.float32)
pro_tensor = torch.tensor(train_pro.T.values, dtype=torch.float32)
metab_tensor = torch.tensor(train_metab.T.values, dtype=torch.float32)

y_gt = ytrain.astype('category').cat.codes
y_gt = torch.tensor(y_gt.values, dtype=torch.int64)

for i in range(2000):

    views = [lip_tensor, metab_tensor, pro_tensor]
    
    # randomly drop an index with low probability
    if np.random.rand() < 0.1:
        idx = np.random.randint(0, len(views))
        views = [v if i != idx else None for i, v in enumerate(views)]

    # get the predictions and distribution of the joint model, and the predictions and distributions of the marginal models
    yhat, poe_dist, yhats, dists = joint_model(views)

    # pass the predictions and distributions to the loss function and update parameters
    loss = joint_model.loss(y_gt, yhat, poe_dist, yhats, dists)

    optimizer.zero_grad()
    loss.backward()
    torch.nn.utils.clip_grad_norm_(joint_model.parameters(), 2.0)
    optimizer.step()

    print(f'Epoch {i+1} loss: {loss.item():.3f}')
# Out:
# Epoch 1 loss: 47.827
# Epoch 2 loss: 46.440
# Epoch 3 loss: 53.320
# Epoch 4 loss: 49.594
# Epoch 5 loss: 51.679
# Epoch 6 loss: 52.942
# Epoch 7 loss: 50.944
# Epoch 8 loss: 54.662
# Epoch 9 loss: 55.193
# Epoch 10 loss: 54.390
# Epoch 11 loss: 49.427
# Epoch 12 loss: 47.891
# Epoch 13 loss: 54.029
# Epoch 14 loss: 51.855
# Epoch 15 loss: 52.437
# Epoch 16 loss: 51.460
# Epoch 17 loss: 35.705
# Epoch 18 loss: 52.759
# Epoch 19 loss: 49.499
# Epoch 20 loss: 51.029
# Epoch 21 loss: 51.358
# Epoch 22 loss: 50.306
# Epoch 23 loss: 36.598
# Epoch 24 loss: 49.435
# Epoch 25 loss: 50.209
# Epoch 26 loss: 48.370
# Epoch 27 loss: 32.815
# Epoch 28 loss: 49.686
# Epoch 29 loss: 45.913
# Epoch 30 loss: 49.588
# Epoch 31 loss: 53.864
# Epoch 32 loss: 48.810
# Epoch 33 loss: 51.799
# Epoch 34 loss: 49.967
# Epoch 35 loss: 46.813
# Epoch 36 loss: 46.936
# Epoch 37 loss: 49.705
# Epoch 38 loss: 49.184
# Epoch 39 loss: 48.433
# Epoch 40 loss: 48.364
# Epoch 41 loss: 45.587
# Epoch 42 loss: 47.011
# Epoch 43 loss: 50.463
# Epoch 44 loss: 49.542
# Epoch 45 loss: 50.795
# Epoch 46 loss: 46.293
# Epoch 47 loss: 49.863
# Epoch 48 loss: 49.243
# Epoch 49 loss: 47.844
# Epoch 50 loss: 49.052
# Epoch 51 loss: 36.712
# Epoch 52 loss: 49.190
# Epoch 53 loss: 54.259
# Epoch 54 loss: 47.004
# Epoch 55 loss: 48.167
# Epoch 56 loss: 48.091
# Epoch 57 loss: 37.374
# Epoch 58 loss: 45.862
# Epoch 59 loss: 51.191
# Epoch 60 loss: 46.694
# Epoch 61 loss: 34.877
# Epoch 62 loss: 49.331
# Epoch 63 loss: 46.411
# Epoch 64 loss: 46.323
# Epoch 65 loss: 49.830
# Epoch 66 loss: 52.137
# Epoch 67 loss: 35.050
# Epoch 68 loss: 49.961
# Epoch 69 loss: 48.110
# Epoch 70 loss: 49.674
# Epoch 71 loss: 49.556
# Epoch 72 loss: 46.079
# Epoch 73 loss: 46.007
# Epoch 74 loss: 47.768
# Epoch 75 loss: 49.013
# Epoch 76 loss: 43.124
# Epoch 77 loss: 47.290
# Epoch 78 loss: 47.352
# Epoch 79 loss: 47.793
# Epoch 80 loss: 46.864
# Epoch 81 loss: 49.283
# Epoch 82 loss: 47.503
# Epoch 83 loss: 47.745
# Epoch 84 loss: 44.984
# Epoch 85 loss: 47.565
# Epoch 86 loss: 45.415
# Epoch 87 loss: 44.946
# Epoch 88 loss: 44.557
# Epoch 89 loss: 50.965
# Epoch 90 loss: 45.883
# Epoch 91 loss: 46.008
# Epoch 92 loss: 47.781
# Epoch 93 loss: 43.761
# Epoch 94 loss: 46.489
# Epoch 95 loss: 45.869
# Epoch 96 loss: 47.546
# Epoch 97 loss: 45.069
# Epoch 98 loss: 45.015
# Epoch 99 loss: 44.851
# Epoch 100 loss: 47.200
# Epoch 101 loss: 46.805
# Epoch 102 loss: 48.332
# Epoch 103 loss: 42.249
# Epoch 104 loss: 43.531
# Epoch 105 loss: 45.398
# Epoch 106 loss: 44.212
# Epoch 107 loss: 45.165
# Epoch 108 loss: 43.615
# Epoch 109 loss: 35.565
# Epoch 110 loss: 43.164
# Epoch 111 loss: 32.124
# Epoch 112 loss: 43.686
# Epoch 113 loss: 47.258
# Epoch 114 loss: 41.564
# Epoch 115 loss: 43.511
# Epoch 116 loss: 45.704
# Epoch 117 loss: 43.996
# Epoch 118 loss: 42.052
# Epoch 119 loss: 31.902
# Epoch 120 loss: 45.715
# Epoch 121 loss: 42.815
# Epoch 122 loss: 45.382
# Epoch 123 loss: 41.708
# Epoch 124 loss: 40.960
# Epoch 125 loss: 30.210
# Epoch 126 loss: 42.341
# Epoch 127 loss: 44.193
# Epoch 128 loss: 44.260
# Epoch 129 loss: 45.109
# Epoch 130 loss: 44.018
# Epoch 131 loss: 42.193
# Epoch 132 loss: 41.627
# Epoch 133 loss: 39.208
# Epoch 134 loss: 42.574
# Epoch 135 loss: 41.120
# Epoch 136 loss: 43.476
# Epoch 137 loss: 44.283
# Epoch 138 loss: 42.340
# Epoch 139 loss: 40.372
# Epoch 140 loss: 42.500
# Epoch 141 loss: 41.511
# Epoch 142 loss: 39.811
# Epoch 143 loss: 41.435
# Epoch 144 loss: 38.023
# Epoch 145 loss: 38.335
# Epoch 146 loss: 41.124
# Epoch 147 loss: 38.305
# Epoch 148 loss: 40.432
# Epoch 149 loss: 40.999
# Epoch 150 loss: 41.118
# Epoch 151 loss: 35.893
# Epoch 152 loss: 38.750
# Epoch 153 loss: 38.286
# Epoch 154 loss: 33.389
# Epoch 155 loss: 36.996
# Epoch 156 loss: 38.385
# Epoch 157 loss: 39.183
# Epoch 158 loss: 37.656
# Epoch 159 loss: 36.691
# Epoch 160 loss: 24.672
# Epoch 161 loss: 41.076
# Epoch 162 loss: 38.936
# Epoch 163 loss: 36.889
# Epoch 164 loss: 39.911
# Epoch 165 loss: 39.470
# Epoch 166 loss: 37.389
# Epoch 167 loss: 39.565
# Epoch 168 loss: 39.036
# Epoch 169 loss: 40.123
# Epoch 170 loss: 35.660
# Epoch 171 loss: 40.007
# Epoch 172 loss: 37.580
# Epoch 173 loss: 34.277
# Epoch 174 loss: 36.243
# Epoch 175 loss: 37.388
# Epoch 176 loss: 36.110
# Epoch 177 loss: 36.591
# Epoch 178 loss: 37.416
# Epoch 179 loss: 37.873
# Epoch 180 loss: 26.105
# Epoch 181 loss: 37.367
# Epoch 182 loss: 37.231
# Epoch 183 loss: 25.302
# Epoch 184 loss: 36.805
# Epoch 185 loss: 24.201
# Epoch 186 loss: 23.743
# Epoch 187 loss: 36.147
# Epoch 188 loss: 37.945
# Epoch 189 loss: 34.249
# Epoch 190 loss: 34.450
# Epoch 191 loss: 34.022
# Epoch 192 loss: 35.572
# Epoch 193 loss: 34.691
# Epoch 194 loss: 36.563
# Epoch 195 loss: 33.689
# Epoch 196 loss: 34.489
# Epoch 197 loss: 35.090
# Epoch 198 loss: 21.996
# Epoch 199 loss: 33.332
# Epoch 200 loss: 32.890
# Epoch 201 loss: 22.840
# Epoch 202 loss: 34.903
# Epoch 203 loss: 32.940
# Epoch 204 loss: 34.309
# Epoch 205 loss: 35.714
# Epoch 206 loss: 36.794
# Epoch 207 loss: 33.868
# Epoch 208 loss: 33.814
# Epoch 209 loss: 35.830
# Epoch 210 loss: 30.811
# Epoch 211 loss: 35.420
# Epoch 212 loss: 32.525
# Epoch 213 loss: 36.254
# Epoch 214 loss: 33.514
# Epoch 215 loss: 33.518
# Epoch 216 loss: 36.817
# Epoch 217 loss: 30.264
# Epoch 218 loss: 35.909
# Epoch 219 loss: 34.204
# Epoch 220 loss: 36.090
# Epoch 221 loss: 33.713
# Epoch 222 loss: 33.031
# Epoch 223 loss: 32.777
# Epoch 224 loss: 26.134
# Epoch 225 loss: 34.215
# Epoch 226 loss: 35.254
# Epoch 227 loss: 32.349
# Epoch 228 loss: 33.705
# Epoch 229 loss: 33.606
# Epoch 230 loss: 32.848
# Epoch 231 loss: 31.771
# Epoch 232 loss: 33.351
# Epoch 233 loss: 32.862
# Epoch 234 loss: 35.732
# Epoch 235 loss: 33.255
# Epoch 236 loss: 35.372
# Epoch 237 loss: 33.026
# Epoch 238 loss: 33.751
# Epoch 239 loss: 32.235
# Epoch 240 loss: 32.566
# Epoch 241 loss: 33.587
# Epoch 242 loss: 31.705
# Epoch 243 loss: 33.723
# Epoch 244 loss: 30.927
# Epoch 245 loss: 33.409
# Epoch 246 loss: 31.499
# Epoch 247 loss: 21.540
# Epoch 248 loss: 32.500
# Epoch 249 loss: 31.662
# Epoch 250 loss: 32.300
# Epoch 251 loss: 31.459
# Epoch 252 loss: 31.711
# Epoch 253 loss: 32.841
# Epoch 254 loss: 32.602
# Epoch 255 loss: 32.561
# Epoch 256 loss: 31.981
# Epoch 257 loss: 33.593
# Epoch 258 loss: 31.485
# Epoch 259 loss: 31.918
# Epoch 260 loss: 21.656
# Epoch 261 loss: 32.889
# Epoch 262 loss: 31.148
# Epoch 263 loss: 31.121
# Epoch 264 loss: 30.750
# Epoch 265 loss: 31.066
# Epoch 266 loss: 32.675
# Epoch 267 loss: 30.363
# Epoch 268 loss: 31.332
# Epoch 269 loss: 31.270
# Epoch 270 loss: 21.323
# Epoch 271 loss: 33.353
# Epoch 272 loss: 31.875
# Epoch 273 loss: 33.085
# Epoch 274 loss: 32.437
# Epoch 275 loss: 30.597
# Epoch 276 loss: 29.352
# Epoch 277 loss: 30.039
# Epoch 278 loss: 31.637
# Epoch 279 loss: 30.350
# Epoch 280 loss: 32.309
# Epoch 281 loss: 31.583
# Epoch 282 loss: 30.317
# Epoch 283 loss: 31.648
# Epoch 284 loss: 32.404
# Epoch 285 loss: 30.506
# Epoch 286 loss: 30.419
# Epoch 287 loss: 31.895
# Epoch 288 loss: 28.822
# Epoch 289 loss: 19.381
# Epoch 290 loss: 31.375
# Epoch 291 loss: 29.418
# Epoch 292 loss: 32.042
# Epoch 293 loss: 30.540
# Epoch 294 loss: 30.807
# Epoch 295 loss: 28.073
# Epoch 296 loss: 30.425
# Epoch 297 loss: 31.026
# Epoch 298 loss: 30.631
# Epoch 299 loss: 29.713
# Epoch 300 loss: 31.104
# Epoch 301 loss: 29.133
# Epoch 302 loss: 31.928
# Epoch 303 loss: 28.342
# Epoch 304 loss: 29.646
# Epoch 305 loss: 30.362
# Epoch 306 loss: 30.516
# Epoch 307 loss: 28.274
# Epoch 308 loss: 31.211
# Epoch 309 loss: 29.072
# Epoch 310 loss: 29.240
# Epoch 311 loss: 32.176
# Epoch 312 loss: 29.703
# Epoch 313 loss: 29.788
# Epoch 314 loss: 29.260
# Epoch 315 loss: 30.594
# Epoch 316 loss: 30.899
# Epoch 317 loss: 30.014
# Epoch 318 loss: 29.809
# Epoch 319 loss: 32.935
# Epoch 320 loss: 29.831
# Epoch 321 loss: 30.477
# Epoch 322 loss: 30.936
# Epoch 323 loss: 20.343
# Epoch 324 loss: 31.921
# Epoch 325 loss: 31.236
# Epoch 326 loss: 20.495
# Epoch 327 loss: 30.188
# Epoch 328 loss: 30.607
# Epoch 329 loss: 31.050
# Epoch 330 loss: 30.260
# Epoch 331 loss: 30.283
# Epoch 332 loss: 31.799
# Epoch 333 loss: 29.266
# Epoch 334 loss: 30.927
# Epoch 335 loss: 28.859
# Epoch 336 loss: 29.158
# Epoch 337 loss: 29.287
# Epoch 338 loss: 19.691
# Epoch 339 loss: 28.522
# Epoch 340 loss: 28.075
# Epoch 341 loss: 29.645
# Epoch 342 loss: 33.345
# Epoch 343 loss: 28.010
# Epoch 344 loss: 29.157
# Epoch 345 loss: 28.887
# Epoch 346 loss: 29.795
# Epoch 347 loss: 28.932
# Epoch 348 loss: 32.394
# Epoch 349 loss: 30.133
# Epoch 350 loss: 29.561
# Epoch 351 loss: 31.348
# Epoch 352 loss: 28.520
# Epoch 353 loss: 29.199
# Epoch 354 loss: 27.868
# Epoch 355 loss: 28.481
# Epoch 356 loss: 29.592
# Epoch 357 loss: 30.375
# Epoch 358 loss: 29.175
# Epoch 359 loss: 28.875
# Epoch 360 loss: 30.192
# Epoch 361 loss: 28.214
# Epoch 362 loss: 29.686
# Epoch 363 loss: 27.607
# Epoch 364 loss: 31.970
# Epoch 365 loss: 29.296
# Epoch 366 loss: 29.172
# Epoch 367 loss: 30.190
# Epoch 368 loss: 28.566
# Epoch 369 loss: 27.106
# Epoch 370 loss: 30.139
# Epoch 371 loss: 18.000
# Epoch 372 loss: 29.606
# Epoch 373 loss: 27.908
# Epoch 374 loss: 29.608
# Epoch 375 loss: 28.886
# Epoch 376 loss: 32.094
# Epoch 377 loss: 27.858
# Epoch 378 loss: 27.953
# Epoch 379 loss: 29.220
# Epoch 380 loss: 29.862
# Epoch 381 loss: 31.206
# Epoch 382 loss: 28.235
# Epoch 383 loss: 29.601
# Epoch 384 loss: 27.106
# Epoch 385 loss: 25.923
# Epoch 386 loss: 26.724
# Epoch 387 loss: 28.017
# Epoch 388 loss: 27.555
# Epoch 389 loss: 28.188
# Epoch 390 loss: 29.540
# Epoch 391 loss: 19.961
# Epoch 392 loss: 29.173
# Epoch 393 loss: 28.625
# Epoch 394 loss: 27.730
# Epoch 395 loss: 29.876
# Epoch 396 loss: 29.478
# Epoch 397 loss: 31.169
# Epoch 398 loss: 28.641
# Epoch 399 loss: 29.442
# Epoch 400 loss: 30.225
# Epoch 401 loss: 29.005
# Epoch 402 loss: 30.516
# Epoch 403 loss: 28.618
# Epoch 404 loss: 29.180
# Epoch 405 loss: 31.199
# Epoch 406 loss: 26.667
# Epoch 407 loss: 28.667
# Epoch 408 loss: 29.411
# Epoch 409 loss: 29.794
# Epoch 410 loss: 30.276
# Epoch 411 loss: 28.353
# Epoch 412 loss: 26.923
# Epoch 413 loss: 29.505
# Epoch 414 loss: 27.977
# Epoch 415 loss: 26.651
# Epoch 416 loss: 28.837
# Epoch 417 loss: 27.870
# Epoch 418 loss: 27.479
# Epoch 419 loss: 29.913
# Epoch 420 loss: 26.731
# Epoch 421 loss: 19.502
# Epoch 422 loss: 28.496
# Epoch 423 loss: 30.325
# Epoch 424 loss: 27.074
# Epoch 425 loss: 28.503
# Epoch 426 loss: 29.248
# Epoch 427 loss: 29.377
# Epoch 428 loss: 27.711
# Epoch 429 loss: 27.866
# Epoch 430 loss: 29.056
# Epoch 431 loss: 28.121
# Epoch 432 loss: 19.053
# Epoch 433 loss: 28.026
# Epoch 434 loss: 28.621
# Epoch 435 loss: 26.891
# Epoch 436 loss: 29.098
# Epoch 437 loss: 29.316
# Epoch 438 loss: 18.502
# Epoch 439 loss: 26.457
# Epoch 440 loss: 18.907
# Epoch 441 loss: 26.915
# Epoch 442 loss: 28.723
# Epoch 443 loss: 27.985
# Epoch 444 loss: 25.663
# Epoch 445 loss: 29.336
# Epoch 446 loss: 27.229
# Epoch 447 loss: 27.708
# Epoch 448 loss: 28.131
# Epoch 449 loss: 28.283
# Epoch 450 loss: 27.098
# Epoch 451 loss: 28.759
# Epoch 452 loss: 29.370
# Epoch 453 loss: 29.190
# Epoch 454 loss: 28.036
# Epoch 455 loss: 27.998
# Epoch 456 loss: 18.190
# Epoch 457 loss: 28.959
# Epoch 458 loss: 29.009
# Epoch 459 loss: 25.791
# Epoch 460 loss: 27.425
# Epoch 461 loss: 28.983
# Epoch 462 loss: 28.390
# Epoch 463 loss: 26.133
# Epoch 464 loss: 27.415
# Epoch 465 loss: 28.837
# Epoch 466 loss: 27.578
# Epoch 467 loss: 28.475
# Epoch 468 loss: 26.288
# Epoch 469 loss: 27.632
# Epoch 470 loss: 28.580
# Epoch 471 loss: 26.297
# Epoch 472 loss: 27.644
# Epoch 473 loss: 27.957
# Epoch 474 loss: 26.832
# Epoch 475 loss: 28.799
# Epoch 476 loss: 26.403
# Epoch 477 loss: 26.387
# Epoch 478 loss: 27.456
# Epoch 479 loss: 27.999
# Epoch 480 loss: 27.794
# Epoch 481 loss: 27.787
# Epoch 482 loss: 30.080
# Epoch 483 loss: 29.093
# Epoch 484 loss: 27.833
# Epoch 485 loss: 28.857
# Epoch 486 loss: 28.833
# Epoch 487 loss: 27.438
# Epoch 488 loss: 29.122
# Epoch 489 loss: 28.198
# Epoch 490 loss: 18.819
# Epoch 491 loss: 27.027
# Epoch 492 loss: 29.805
# Epoch 493 loss: 36.265
# Epoch 494 loss: 33.116
# Epoch 495 loss: 28.460
# Epoch 496 loss: 31.347
# Epoch 497 loss: 33.292
# Epoch 498 loss: 28.673
# Epoch 499 loss: 28.419
# Epoch 500 loss: 28.720
# Epoch 501 loss: 29.849
# Epoch 502 loss: 29.383
# Epoch 503 loss: 29.761
# Epoch 504 loss: 31.070
# Epoch 505 loss: 29.512
# Epoch 506 loss: 28.437
# Epoch 507 loss: 27.090
# Epoch 508 loss: 29.016
# Epoch 509 loss: 27.990
# Epoch 510 loss: 26.511
# Epoch 511 loss: 28.824
# Epoch 512 loss: 28.288
# Epoch 513 loss: 28.612
# Epoch 514 loss: 30.945
# Epoch 515 loss: 29.292
# Epoch 516 loss: 29.581
# Epoch 517 loss: 25.896
# Epoch 518 loss: 28.513
# Epoch 519 loss: 17.733
# Epoch 520 loss: 27.167
# Epoch 521 loss: 27.257
# Epoch 522 loss: 28.430
# Epoch 523 loss: 30.142
# Epoch 524 loss: 27.968
# Epoch 525 loss: 27.808
# Epoch 526 loss: 26.914
# Epoch 527 loss: 28.687
# Epoch 528 loss: 27.377
# Epoch 529 loss: 28.281
# Epoch 530 loss: 27.657
# Epoch 531 loss: 28.180
# Epoch 532 loss: 27.432
# Epoch 533 loss: 27.142
# Epoch 534 loss: 30.163
# Epoch 535 loss: 29.158
# Epoch 536 loss: 28.535
# Epoch 537 loss: 27.758
# Epoch 538 loss: 29.098
# Epoch 539 loss: 28.300
# Epoch 540 loss: 26.496
# Epoch 541 loss: 27.011
# Epoch 542 loss: 27.397
# Epoch 543 loss: 28.603
# Epoch 544 loss: 18.426
# Epoch 545 loss: 28.607
# Epoch 546 loss: 26.180
# Epoch 547 loss: 28.616
# Epoch 548 loss: 30.149
# Epoch 549 loss: 27.672
# Epoch 550 loss: 27.570
# Epoch 551 loss: 29.632
# Epoch 552 loss: 25.707
# Epoch 553 loss: 27.412
# Epoch 554 loss: 29.109
# Epoch 555 loss: 26.981
# Epoch 556 loss: 28.599
# Epoch 557 loss: 27.054
# Epoch 558 loss: 26.147
# Epoch 559 loss: 28.742
# Epoch 560 loss: 27.176
# Epoch 561 loss: 18.382
# Epoch 562 loss: 27.586
# Epoch 563 loss: 27.252
# Epoch 564 loss: 29.525
# Epoch 565 loss: 29.218
# Epoch 566 loss: 16.998
# Epoch 567 loss: 27.543
# Epoch 568 loss: 19.665
# Epoch 569 loss: 29.410
# Epoch 570 loss: 25.280
# Epoch 571 loss: 26.766
# Epoch 572 loss: 31.170
# Epoch 573 loss: 27.011
# Epoch 574 loss: 27.872
# Epoch 575 loss: 28.280
# Epoch 576 loss: 27.978
# Epoch 577 loss: 19.197
# Epoch 578 loss: 26.780
# Epoch 579 loss: 26.071
# Epoch 580 loss: 26.705
# Epoch 581 loss: 26.454
# Epoch 582 loss: 26.745
# Epoch 583 loss: 28.105
# Epoch 584 loss: 25.863
# Epoch 585 loss: 27.840
# Epoch 586 loss: 26.496
# Epoch 587 loss: 27.475
# Epoch 588 loss: 27.839
# Epoch 589 loss: 26.516
# Epoch 590 loss: 27.888
# Epoch 591 loss: 27.821
# Epoch 592 loss: 30.427
# Epoch 593 loss: 27.077
# Epoch 594 loss: 28.951
# Epoch 595 loss: 25.600
# Epoch 596 loss: 26.265
# Epoch 597 loss: 17.314
# Epoch 598 loss: 30.032
# Epoch 599 loss: 27.826
# Epoch 600 loss: 23.521
# Epoch 601 loss: 29.943
# Epoch 602 loss: 29.142
# Epoch 603 loss: 27.026
# Epoch 604 loss: 27.496
# Epoch 605 loss: 28.389
# Epoch 606 loss: 26.970
# Epoch 607 loss: 26.000
# Epoch 608 loss: 27.295
# Epoch 609 loss: 27.885
# Epoch 610 loss: 24.841
# Epoch 611 loss: 27.567
# Epoch 612 loss: 30.275
# Epoch 613 loss: 27.799
# Epoch 614 loss: 26.331
# Epoch 615 loss: 26.776
# Epoch 616 loss: 18.337
# Epoch 617 loss: 26.794
# Epoch 618 loss: 25.139
# Epoch 619 loss: 25.581
# Epoch 620 loss: 25.143
# Epoch 621 loss: 29.272
# Epoch 622 loss: 28.145
# Epoch 623 loss: 27.072
# Epoch 624 loss: 28.514
# Epoch 625 loss: 28.634
# Epoch 626 loss: 28.740
# Epoch 627 loss: 27.587
# Epoch 628 loss: 26.956
# Epoch 629 loss: 28.379
# Epoch 630 loss: 26.478
# Epoch 631 loss: 26.979
# Epoch 632 loss: 25.830
# Epoch 633 loss: 29.816
# Epoch 634 loss: 26.560
# Epoch 635 loss: 26.749
# Epoch 636 loss: 28.437
# Epoch 637 loss: 29.509
# Epoch 638 loss: 26.396
# Epoch 639 loss: 27.773
# Epoch 640 loss: 27.000
# Epoch 641 loss: 29.103
# Epoch 642 loss: 28.427
# Epoch 643 loss: 24.429
# Epoch 644 loss: 27.401
# Epoch 645 loss: 27.892
# Epoch 646 loss: 26.515
# Epoch 647 loss: 16.949
# Epoch 648 loss: 27.126
# Epoch 649 loss: 28.305
# Epoch 650 loss: 27.106
# Epoch 651 loss: 24.972
# Epoch 652 loss: 25.868
# Epoch 653 loss: 27.170
# Epoch 654 loss: 25.781
# Epoch 655 loss: 27.471
# Epoch 656 loss: 27.234
# Epoch 657 loss: 27.293
# Epoch 658 loss: 19.257
# Epoch 659 loss: 26.236
# Epoch 660 loss: 27.150
# Epoch 661 loss: 27.835
# Epoch 662 loss: 27.673
# Epoch 663 loss: 27.659
# Epoch 664 loss: 27.707
# Epoch 665 loss: 28.149
# Epoch 666 loss: 23.781
# Epoch 667 loss: 30.604
# Epoch 668 loss: 27.811
# Epoch 669 loss: 17.671
# Epoch 670 loss: 28.121
# Epoch 671 loss: 27.297
# Epoch 672 loss: 26.768
# Epoch 673 loss: 25.719
# Epoch 674 loss: 27.203
# Epoch 675 loss: 25.460
# Epoch 676 loss: 26.242
# Epoch 677 loss: 26.811
# Epoch 678 loss: 26.255
# Epoch 679 loss: 26.673
# Epoch 680 loss: 16.611
# Epoch 681 loss: 26.815
# Epoch 682 loss: 28.432
# Epoch 683 loss: 29.346
# Epoch 684 loss: 25.149
# Epoch 685 loss: 27.645
# Epoch 686 loss: 28.120
# Epoch 687 loss: 27.234
# Epoch 688 loss: 30.313
# Epoch 689 loss: 24.642
# Epoch 690 loss: 27.663
# Epoch 691 loss: 29.625
# Epoch 692 loss: 26.287
# Epoch 693 loss: 16.983
# Epoch 694 loss: 25.981
# Epoch 695 loss: 25.769
# Epoch 696 loss: 27.108
# Epoch 697 loss: 26.446
# Epoch 698 loss: 28.567
# Epoch 699 loss: 27.419
# Epoch 700 loss: 27.234
# Epoch 701 loss: 27.927
# Epoch 702 loss: 28.456
# Epoch 703 loss: 26.491
# Epoch 704 loss: 28.646
# Epoch 705 loss: 24.108
# Epoch 706 loss: 26.042
# Epoch 707 loss: 26.903
# Epoch 708 loss: 27.501
# Epoch 709 loss: 28.402
# Epoch 710 loss: 31.673
# Epoch 711 loss: 29.088
# Epoch 712 loss: 27.595
# Epoch 713 loss: 17.643
# Epoch 714 loss: 26.577
# Epoch 715 loss: 27.239
# Epoch 716 loss: 17.751
# Epoch 717 loss: 26.373
# Epoch 718 loss: 26.738
# Epoch 719 loss: 26.521
# Epoch 720 loss: 26.449
# Epoch 721 loss: 16.700
# Epoch 722 loss: 25.815
# Epoch 723 loss: 24.262
# Epoch 724 loss: 26.401
# Epoch 725 loss: 27.977
# Epoch 726 loss: 26.673
# Epoch 727 loss: 27.151
# Epoch 728 loss: 17.685
# Epoch 729 loss: 26.020
# Epoch 730 loss: 25.985
# Epoch 731 loss: 28.470
# Epoch 732 loss: 27.820
# Epoch 733 loss: 27.444
# Epoch 734 loss: 27.151
# Epoch 735 loss: 26.140
# Epoch 736 loss: 26.478
# Epoch 737 loss: 24.464
# Epoch 738 loss: 27.135
# Epoch 739 loss: 24.689
# Epoch 740 loss: 27.821
# Epoch 741 loss: 23.509
# Epoch 742 loss: 25.534
# Epoch 743 loss: 25.080
# Epoch 744 loss: 27.354
# Epoch 745 loss: 25.530
# Epoch 746 loss: 26.276
# Epoch 747 loss: 25.373
# Epoch 748 loss: 25.482
# Epoch 749 loss: 18.313
# Epoch 750 loss: 25.953
# Epoch 751 loss: 27.161
# Epoch 752 loss: 27.207
# Epoch 753 loss: 27.974
# Epoch 754 loss: 25.246
# Epoch 755 loss: 26.163
# Epoch 756 loss: 28.377
# Epoch 757 loss: 26.331
# Epoch 758 loss: 26.475
# Epoch 759 loss: 28.145
# Epoch 760 loss: 26.131
# Epoch 761 loss: 28.089
# Epoch 762 loss: 29.139
# Epoch 763 loss: 27.964
# Epoch 764 loss: 27.526
# Epoch 765 loss: 26.977
# Epoch 766 loss: 25.873
# Epoch 767 loss: 24.717
# Epoch 768 loss: 24.888
# Epoch 769 loss: 25.842
# Epoch 770 loss: 24.115
# Epoch 771 loss: 25.705
# Epoch 772 loss: 18.484
# Epoch 773 loss: 16.382
# Epoch 774 loss: 28.177
# Epoch 775 loss: 24.969
# Epoch 776 loss: 27.182
# Epoch 777 loss: 26.679
# Epoch 778 loss: 15.654
# Epoch 779 loss: 25.881
# Epoch 780 loss: 23.900
# Epoch 781 loss: 26.724
# Epoch 782 loss: 17.496
# Epoch 783 loss: 24.942
# Epoch 784 loss: 24.664
# Epoch 785 loss: 28.075
# Epoch 786 loss: 18.341
# Epoch 787 loss: 25.898
# Epoch 788 loss: 26.256
# Epoch 789 loss: 26.237
# Epoch 790 loss: 25.827
# Epoch 791 loss: 25.813
# Epoch 792 loss: 24.041
# Epoch 793 loss: 27.242
# Epoch 794 loss: 28.160
# Epoch 795 loss: 25.535
# Epoch 796 loss: 26.759
# Epoch 797 loss: 29.609
# Epoch 798 loss: 27.356
# Epoch 799 loss: 25.411
# Epoch 800 loss: 25.462
# Epoch 801 loss: 26.434
# Epoch 802 loss: 24.711
# Epoch 803 loss: 17.411
# Epoch 804 loss: 24.804
# Epoch 805 loss: 26.097
# Epoch 806 loss: 26.221
# Epoch 807 loss: 26.270
# Epoch 808 loss: 25.386
# Epoch 809 loss: 24.397
# Epoch 810 loss: 24.053
# Epoch 811 loss: 25.941
# Epoch 812 loss: 25.670
# Epoch 813 loss: 28.412
# Epoch 814 loss: 27.472
# Epoch 815 loss: 26.434
# Epoch 816 loss: 27.508
# Epoch 817 loss: 24.898
# Epoch 818 loss: 26.685
# Epoch 819 loss: 27.200
# Epoch 820 loss: 28.871
# Epoch 821 loss: 27.291
# Epoch 822 loss: 25.388
# Epoch 823 loss: 26.257
# Epoch 824 loss: 28.132
# Epoch 825 loss: 26.196
# Epoch 826 loss: 24.503
# Epoch 827 loss: 25.412
# Epoch 828 loss: 30.685
# Epoch 829 loss: 24.506
# Epoch 830 loss: 24.223
# Epoch 831 loss: 27.171
# Epoch 832 loss: 25.195
# Epoch 833 loss: 24.504
# Epoch 834 loss: 17.043
# Epoch 835 loss: 19.996
# Epoch 836 loss: 24.280
# Epoch 837 loss: 24.486
# Epoch 838 loss: 25.401
# Epoch 839 loss: 27.476
# Epoch 840 loss: 24.159
# Epoch 841 loss: 27.713
# Epoch 842 loss: 22.938
# Epoch 843 loss: 23.728
# Epoch 844 loss: 27.562
# Epoch 845 loss: 26.184
# Epoch 846 loss: 23.986
# Epoch 847 loss: 27.098
# Epoch 848 loss: 28.344
# Epoch 849 loss: 25.891
# Epoch 850 loss: 16.820
# Epoch 851 loss: 24.218
# Epoch 852 loss: 26.201
# Epoch 853 loss: 18.917
# Epoch 854 loss: 26.133
# Epoch 855 loss: 25.718
# Epoch 856 loss: 28.664
# Epoch 857 loss: 27.350
# Epoch 858 loss: 26.252
# Epoch 859 loss: 26.029
# Epoch 860 loss: 26.615
# Epoch 861 loss: 28.063
# Epoch 862 loss: 25.906
# Epoch 863 loss: 17.129
# Epoch 864 loss: 23.231
# Epoch 865 loss: 25.416
# Epoch 866 loss: 25.203
# Epoch 867 loss: 25.982
# Epoch 868 loss: 28.006
# Epoch 869 loss: 25.898
# Epoch 870 loss: 27.074
# Epoch 871 loss: 24.226
# Epoch 872 loss: 25.508
# Epoch 873 loss: 26.727
# Epoch 874 loss: 27.303
# Epoch 875 loss: 28.146
# Epoch 876 loss: 23.559
# Epoch 877 loss: 18.801
# Epoch 878 loss: 26.626
# Epoch 879 loss: 24.206
# Epoch 880 loss: 26.449
# Epoch 881 loss: 27.098
# Epoch 882 loss: 25.348
# Epoch 883 loss: 25.677
# Epoch 884 loss: 25.306
# Epoch 885 loss: 28.259
# Epoch 886 loss: 25.897
# Epoch 887 loss: 15.465
# Epoch 888 loss: 26.093
# Epoch 889 loss: 26.388
# Epoch 890 loss: 23.952
# Epoch 891 loss: 24.988
# Epoch 892 loss: 24.350
# Epoch 893 loss: 26.784
# Epoch 894 loss: 26.499
# Epoch 895 loss: 25.697
# Epoch 896 loss: 24.901
# Epoch 897 loss: 23.956
# Epoch 898 loss: 25.414
# Epoch 899 loss: 24.353
# Epoch 900 loss: 22.346
# Epoch 901 loss: 25.005
# Epoch 902 loss: 26.189
# Epoch 903 loss: 22.215
# Epoch 904 loss: 25.458
# Epoch 905 loss: 23.989
# Epoch 906 loss: 26.912
# Epoch 907 loss: 24.551
# Epoch 908 loss: 25.799
# Epoch 909 loss: 27.030
# Epoch 910 loss: 29.117
# Epoch 911 loss: 18.367
# Epoch 912 loss: 23.927
# Epoch 913 loss: 24.072
# Epoch 914 loss: 24.909
# Epoch 915 loss: 25.693
# Epoch 916 loss: 25.036
# Epoch 917 loss: 25.275
# Epoch 918 loss: 25.260
# Epoch 919 loss: 24.560
# Epoch 920 loss: 24.632
# Epoch 921 loss: 25.270
# Epoch 922 loss: 24.591
# Epoch 923 loss: 25.033
# Epoch 924 loss: 24.887
# Epoch 925 loss: 26.439
# Epoch 926 loss: 27.357
# Epoch 927 loss: 23.849
# Epoch 928 loss: 24.339
# Epoch 929 loss: 25.077
# Epoch 930 loss: 16.262
# Epoch 931 loss: 26.860
# Epoch 932 loss: 23.056
# Epoch 933 loss: 25.452
# Epoch 934 loss: 25.564
# Epoch 935 loss: 24.894
# Epoch 936 loss: 24.821
# Epoch 937 loss: 25.598
# Epoch 938 loss: 25.251
# Epoch 939 loss: 27.021
# Epoch 940 loss: 25.153
# Epoch 941 loss: 25.770
# Epoch 942 loss: 27.434
# Epoch 943 loss: 26.217
# Epoch 944 loss: 23.064
# Epoch 945 loss: 23.261
# Epoch 946 loss: 27.910
# Epoch 947 loss: 24.507
# Epoch 948 loss: 23.035
# Epoch 949 loss: 27.296
# Epoch 950 loss: 18.184
# Epoch 951 loss: 26.864
# Epoch 952 loss: 27.670
# Epoch 953 loss: 25.397
# Epoch 954 loss: 23.972
# Epoch 955 loss: 25.092
# Epoch 956 loss: 25.291
# Epoch 957 loss: 23.455
# Epoch 958 loss: 23.889
# Epoch 959 loss: 24.128
# Epoch 960 loss: 28.845
# Epoch 961 loss: 26.064
# Epoch 962 loss: 24.112
# Epoch 963 loss: 25.925
# Epoch 964 loss: 21.558
# Epoch 965 loss: 23.031
# Epoch 966 loss: 21.924
# Epoch 967 loss: 18.551
# Epoch 968 loss: 22.826
# Epoch 969 loss: 24.567
# Epoch 970 loss: 27.028
# Epoch 971 loss: 25.954
# Epoch 972 loss: 25.854
# Epoch 973 loss: 26.063
# Epoch 974 loss: 19.374
# Epoch 975 loss: 26.237
# Epoch 976 loss: 16.384
# Epoch 977 loss: 26.337
# Epoch 978 loss: 23.303
# Epoch 979 loss: 25.566
# Epoch 980 loss: 25.809
# Epoch 981 loss: 24.583
# Epoch 982 loss: 26.703
# Epoch 983 loss: 26.263
# Epoch 984 loss: 26.169
# Epoch 985 loss: 25.728
# Epoch 986 loss: 26.960
# Epoch 987 loss: 23.780
# Epoch 988 loss: 26.356
# Epoch 989 loss: 25.252
# Epoch 990 loss: 26.999
# Epoch 991 loss: 25.457
# Epoch 992 loss: 26.702
# Epoch 993 loss: 28.386
# Epoch 994 loss: 26.176
# Epoch 995 loss: 24.219
# Epoch 996 loss: 24.093
# Epoch 997 loss: 26.290
# Epoch 998 loss: 20.302
# Epoch 999 loss: 25.402
# Epoch 1000 loss: 17.446
# Epoch 1001 loss: 25.309
# Epoch 1002 loss: 26.967
# Epoch 1003 loss: 26.611
# Epoch 1004 loss: 23.782
# Epoch 1005 loss: 26.624
# Epoch 1006 loss: 25.541
# Epoch 1007 loss: 26.899
# Epoch 1008 loss: 27.338
# Epoch 1009 loss: 24.814
# Epoch 1010 loss: 23.371
# Epoch 1011 loss: 25.904
# Epoch 1012 loss: 24.495
# Epoch 1013 loss: 25.079
# Epoch 1014 loss: 24.215
# Epoch 1015 loss: 25.616
# Epoch 1016 loss: 24.653
# Epoch 1017 loss: 25.578
# Epoch 1018 loss: 27.340
# Epoch 1019 loss: 28.178
# Epoch 1020 loss: 21.798
# Epoch 1021 loss: 23.874
# Epoch 1022 loss: 23.911
# Epoch 1023 loss: 23.724
# Epoch 1024 loss: 25.301
# Epoch 1025 loss: 27.329
# Epoch 1026 loss: 24.461
# Epoch 1027 loss: 26.996
# Epoch 1028 loss: 24.748
# Epoch 1029 loss: 26.503
# Epoch 1030 loss: 27.041
# Epoch 1031 loss: 23.374
# Epoch 1032 loss: 23.263
# Epoch 1033 loss: 25.769
# Epoch 1034 loss: 27.173
# Epoch 1035 loss: 24.759
# Epoch 1036 loss: 27.089
# Epoch 1037 loss: 24.799
# Epoch 1038 loss: 24.807
# Epoch 1039 loss: 22.867
# Epoch 1040 loss: 25.884
# Epoch 1041 loss: 23.198
# Epoch 1042 loss: 26.301
# Epoch 1043 loss: 24.527
# Epoch 1044 loss: 26.912
# Epoch 1045 loss: 25.996
# Epoch 1046 loss: 25.018
# Epoch 1047 loss: 26.827
# Epoch 1048 loss: 24.071
# Epoch 1049 loss: 24.343
# Epoch 1050 loss: 24.187
# Epoch 1051 loss: 25.433
# Epoch 1052 loss: 22.606
# Epoch 1053 loss: 23.478
# Epoch 1054 loss: 26.985
# Epoch 1055 loss: 27.861
# Epoch 1056 loss: 25.129
# Epoch 1057 loss: 26.438
# Epoch 1058 loss: 26.925
# Epoch 1059 loss: 23.153
# Epoch 1060 loss: 22.563
# Epoch 1061 loss: 28.659
# Epoch 1062 loss: 29.740
# Epoch 1063 loss: 25.241
# Epoch 1064 loss: 24.963
# Epoch 1065 loss: 27.940
# Epoch 1066 loss: 25.755
# Epoch 1067 loss: 24.394
# Epoch 1068 loss: 26.380
# Epoch 1069 loss: 26.792
# Epoch 1070 loss: 27.685
# Epoch 1071 loss: 20.112
# Epoch 1072 loss: 24.410
# Epoch 1073 loss: 24.457
# Epoch 1074 loss: 24.551
# Epoch 1075 loss: 26.638
# Epoch 1076 loss: 24.788
# Epoch 1077 loss: 23.733
# Epoch 1078 loss: 23.191
# Epoch 1079 loss: 26.998
# Epoch 1080 loss: 24.831
# Epoch 1081 loss: 15.829
# Epoch 1082 loss: 25.060
# Epoch 1083 loss: 24.340
# Epoch 1084 loss: 29.310
# Epoch 1085 loss: 25.192
# Epoch 1086 loss: 23.634
# Epoch 1087 loss: 25.081
# Epoch 1088 loss: 24.865
# Epoch 1089 loss: 25.186
# Epoch 1090 loss: 25.919
# Epoch 1091 loss: 25.394
# Epoch 1092 loss: 22.673
# Epoch 1093 loss: 27.004
# Epoch 1094 loss: 25.980
# Epoch 1095 loss: 24.710
# Epoch 1096 loss: 24.399
# Epoch 1097 loss: 25.316
# Epoch 1098 loss: 24.449
# Epoch 1099 loss: 18.142
# Epoch 1100 loss: 24.711
# Epoch 1101 loss: 26.997
# Epoch 1102 loss: 24.949
# Epoch 1103 loss: 25.513
# Epoch 1104 loss: 16.527
# Epoch 1105 loss: 24.985
# Epoch 1106 loss: 24.622
# Epoch 1107 loss: 23.678
# Epoch 1108 loss: 24.585
# Epoch 1109 loss: 24.320
# Epoch 1110 loss: 26.195
# Epoch 1111 loss: 22.636
# Epoch 1112 loss: 24.525
# Epoch 1113 loss: 24.535
# Epoch 1114 loss: 23.812
# Epoch 1115 loss: 26.215
# Epoch 1116 loss: 23.350
# Epoch 1117 loss: 25.028
# Epoch 1118 loss: 25.002
# Epoch 1119 loss: 25.093
# Epoch 1120 loss: 23.854
# Epoch 1121 loss: 17.032
# Epoch 1122 loss: 16.021
# Epoch 1123 loss: 23.762
# Epoch 1124 loss: 23.681
# Epoch 1125 loss: 26.708
# Epoch 1126 loss: 25.681
# Epoch 1127 loss: 23.998
# Epoch 1128 loss: 21.858
# Epoch 1129 loss: 17.876
# Epoch 1130 loss: 25.229
# Epoch 1131 loss: 22.728
# Epoch 1132 loss: 28.807
# Epoch 1133 loss: 27.384
# Epoch 1134 loss: 24.586
# Epoch 1135 loss: 23.332
# Epoch 1136 loss: 26.191
# Epoch 1137 loss: 24.381
# Epoch 1138 loss: 27.054
# Epoch 1139 loss: 24.158
# Epoch 1140 loss: 24.324
# Epoch 1141 loss: 26.029
# Epoch 1142 loss: 24.083
# Epoch 1143 loss: 23.051
# Epoch 1144 loss: 25.377
# Epoch 1145 loss: 29.028
# Epoch 1146 loss: 26.100
# Epoch 1147 loss: 25.827
# Epoch 1148 loss: 22.633
# Epoch 1149 loss: 24.581
# Epoch 1150 loss: 25.682
# Epoch 1151 loss: 23.250
# Epoch 1152 loss: 17.234
# Epoch 1153 loss: 18.314
# Epoch 1154 loss: 26.316
# Epoch 1155 loss: 25.587
# Epoch 1156 loss: 28.032
# Epoch 1157 loss: 24.995
# Epoch 1158 loss: 23.069
# Epoch 1159 loss: 26.544
# Epoch 1160 loss: 25.998
# Epoch 1161 loss: 24.746
# Epoch 1162 loss: 22.421
# Epoch 1163 loss: 17.502
# Epoch 1164 loss: 24.880
# Epoch 1165 loss: 24.272
# Epoch 1166 loss: 24.817
# Epoch 1167 loss: 26.445
# Epoch 1168 loss: 24.029
# Epoch 1169 loss: 26.889
# Epoch 1170 loss: 24.429
# Epoch 1171 loss: 24.466
# Epoch 1172 loss: 24.868
# Epoch 1173 loss: 24.168
# Epoch 1174 loss: 23.758
# Epoch 1175 loss: 23.674
# Epoch 1176 loss: 17.012
# Epoch 1177 loss: 19.743
# Epoch 1178 loss: 23.374
# Epoch 1179 loss: 23.874
# Epoch 1180 loss: 24.232
# Epoch 1181 loss: 23.418
# Epoch 1182 loss: 16.162
# Epoch 1183 loss: 24.916
# Epoch 1184 loss: 24.750
# Epoch 1185 loss: 25.274
# Epoch 1186 loss: 23.612
# Epoch 1187 loss: 25.239
# Epoch 1188 loss: 26.744
# Epoch 1189 loss: 25.127
# Epoch 1190 loss: 24.711
# Epoch 1191 loss: 23.979
# Epoch 1192 loss: 24.755
# Epoch 1193 loss: 23.460
# Epoch 1194 loss: 24.668
# Epoch 1195 loss: 24.841
# Epoch 1196 loss: 23.366
# Epoch 1197 loss: 23.398
# Epoch 1198 loss: 22.875
# Epoch 1199 loss: 26.067
# Epoch 1200 loss: 25.977
# Epoch 1201 loss: 26.078
# Epoch 1202 loss: 24.127
# Epoch 1203 loss: 24.559
# Epoch 1204 loss: 23.415
# Epoch 1205 loss: 24.596
# Epoch 1206 loss: 24.722
# Epoch 1207 loss: 22.619
# Epoch 1208 loss: 25.766
# Epoch 1209 loss: 19.145
# Epoch 1210 loss: 24.247
# Epoch 1211 loss: 27.402
# Epoch 1212 loss: 27.732
# Epoch 1213 loss: 24.536
# Epoch 1214 loss: 24.969
# Epoch 1215 loss: 14.104
# Epoch 1216 loss: 16.207
# Epoch 1217 loss: 26.023
# Epoch 1218 loss: 23.877
# Epoch 1219 loss: 25.253
# Epoch 1220 loss: 22.969
# Epoch 1221 loss: 26.390
# Epoch 1222 loss: 24.934
# Epoch 1223 loss: 26.271
# Epoch 1224 loss: 24.082
# Epoch 1225 loss: 21.494
# Epoch 1226 loss: 23.675
# Epoch 1227 loss: 23.349
# Epoch 1228 loss: 24.818
# Epoch 1229 loss: 23.485
# Epoch 1230 loss: 16.816
# Epoch 1231 loss: 24.635
# Epoch 1232 loss: 24.938
# Epoch 1233 loss: 27.280
# Epoch 1234 loss: 23.605
# Epoch 1235 loss: 22.715
# Epoch 1236 loss: 25.586
# Epoch 1237 loss: 25.296
# Epoch 1238 loss: 24.630
# Epoch 1239 loss: 22.910
# Epoch 1240 loss: 24.357
# Epoch 1241 loss: 23.314
# Epoch 1242 loss: 24.584
# Epoch 1243 loss: 23.499
# Epoch 1244 loss: 21.200
# Epoch 1245 loss: 29.082
# Epoch 1246 loss: 22.325
# Epoch 1247 loss: 25.537
# Epoch 1248 loss: 26.018
# Epoch 1249 loss: 23.014
# Epoch 1250 loss: 24.125
# Epoch 1251 loss: 23.641
# Epoch 1252 loss: 23.349
# Epoch 1253 loss: 25.371
# Epoch 1254 loss: 23.471
# Epoch 1255 loss: 23.912
# Epoch 1256 loss: 24.696
# Epoch 1257 loss: 24.481
# Epoch 1258 loss: 26.108
# Epoch 1259 loss: 24.886
# Epoch 1260 loss: 24.848
# Epoch 1261 loss: 25.581
# Epoch 1262 loss: 19.194
# Epoch 1263 loss: 25.714
# Epoch 1264 loss: 23.547
# Epoch 1265 loss: 23.286
# Epoch 1266 loss: 22.876
# Epoch 1267 loss: 24.505
# Epoch 1268 loss: 26.398
# Epoch 1269 loss: 22.917
# Epoch 1270 loss: 24.392
# Epoch 1271 loss: 17.564
# Epoch 1272 loss: 26.926
# Epoch 1273 loss: 23.743
# Epoch 1274 loss: 21.582
# Epoch 1275 loss: 24.598
# Epoch 1276 loss: 25.216
# Epoch 1277 loss: 22.550
# Epoch 1278 loss: 24.507
# Epoch 1279 loss: 26.145
# Epoch 1280 loss: 22.519
# Epoch 1281 loss: 15.684
# Epoch 1282 loss: 23.867
# Epoch 1283 loss: 23.078
# Epoch 1284 loss: 21.176
# Epoch 1285 loss: 25.164
# Epoch 1286 loss: 24.432
# Epoch 1287 loss: 26.053
# Epoch 1288 loss: 22.561
# Epoch 1289 loss: 25.799
# Epoch 1290 loss: 25.707
# Epoch 1291 loss: 23.407
# Epoch 1292 loss: 23.043
# Epoch 1293 loss: 23.931
# Epoch 1294 loss: 24.863
# Epoch 1295 loss: 24.337
# Epoch 1296 loss: 15.882
# Epoch 1297 loss: 23.877
# Epoch 1298 loss: 26.950
# Epoch 1299 loss: 23.818
# Epoch 1300 loss: 22.060
# Epoch 1301 loss: 25.025
# Epoch 1302 loss: 26.057
# Epoch 1303 loss: 21.174
# Epoch 1304 loss: 26.418
# Epoch 1305 loss: 24.316
# Epoch 1306 loss: 23.528
# Epoch 1307 loss: 24.150
# Epoch 1308 loss: 27.317
# Epoch 1309 loss: 26.029
# Epoch 1310 loss: 23.774
# Epoch 1311 loss: 22.565
# Epoch 1312 loss: 22.755
# Epoch 1313 loss: 22.473
# Epoch 1314 loss: 23.832
# Epoch 1315 loss: 24.838
# Epoch 1316 loss: 21.967
# Epoch 1317 loss: 23.872
# Epoch 1318 loss: 22.781
# Epoch 1319 loss: 27.170
# Epoch 1320 loss: 24.259
# Epoch 1321 loss: 22.992
# Epoch 1322 loss: 25.444
# Epoch 1323 loss: 24.053
# Epoch 1324 loss: 26.402
# Epoch 1325 loss: 15.025
# Epoch 1326 loss: 22.145
# Epoch 1327 loss: 25.464
# Epoch 1328 loss: 24.962
# Epoch 1329 loss: 23.217
# Epoch 1330 loss: 24.745
# Epoch 1331 loss: 25.362
# Epoch 1332 loss: 24.545
# Epoch 1333 loss: 23.375
# Epoch 1334 loss: 16.073
# Epoch 1335 loss: 28.257
# Epoch 1336 loss: 24.468
# Epoch 1337 loss: 24.912
# Epoch 1338 loss: 27.050
# Epoch 1339 loss: 21.650
# Epoch 1340 loss: 26.311
# Epoch 1341 loss: 24.407
# Epoch 1342 loss: 27.540
# Epoch 1343 loss: 25.735
# Epoch 1344 loss: 23.522
# Epoch 1345 loss: 22.352
# Epoch 1346 loss: 24.127
# Epoch 1347 loss: 26.171
# Epoch 1348 loss: 25.651
# Epoch 1349 loss: 23.932
# Epoch 1350 loss: 25.310
# Epoch 1351 loss: 24.557
# Epoch 1352 loss: 14.881
# Epoch 1353 loss: 22.591
# Epoch 1354 loss: 24.502
# Epoch 1355 loss: 26.318
# Epoch 1356 loss: 25.622
# Epoch 1357 loss: 22.668
# Epoch 1358 loss: 27.126
# Epoch 1359 loss: 24.995
# Epoch 1360 loss: 21.485
# Epoch 1361 loss: 20.491
# Epoch 1362 loss: 23.057
# Epoch 1363 loss: 22.886
# Epoch 1364 loss: 27.042
# Epoch 1365 loss: 22.810
# Epoch 1366 loss: 22.604
# Epoch 1367 loss: 23.862
# Epoch 1368 loss: 26.670
# Epoch 1369 loss: 24.558
# Epoch 1370 loss: 24.555
# Epoch 1371 loss: 24.896
# Epoch 1372 loss: 26.153
# Epoch 1373 loss: 25.063
# Epoch 1374 loss: 24.334
# Epoch 1375 loss: 26.256
# Epoch 1376 loss: 30.711
# Epoch 1377 loss: 16.172
# Epoch 1378 loss: 29.436
# Epoch 1379 loss: 24.386
# Epoch 1380 loss: 25.785
# Epoch 1381 loss: 27.196
# Epoch 1382 loss: 24.883
# Epoch 1383 loss: 26.306
# Epoch 1384 loss: 27.081
# Epoch 1385 loss: 24.367
# Epoch 1386 loss: 25.411
# Epoch 1387 loss: 26.767
# Epoch 1388 loss: 25.673
# Epoch 1389 loss: 25.300
# Epoch 1390 loss: 26.425
# Epoch 1391 loss: 14.889
# Epoch 1392 loss: 24.967
# Epoch 1393 loss: 29.335
# Epoch 1394 loss: 31.594
# Epoch 1395 loss: 24.912
# Epoch 1396 loss: 23.645
# Epoch 1397 loss: 25.101
# Epoch 1398 loss: 28.564
# Epoch 1399 loss: 28.195
# Epoch 1400 loss: 24.249
# Epoch 1401 loss: 24.459
# Epoch 1402 loss: 26.140
# Epoch 1403 loss: 23.686
# Epoch 1404 loss: 22.231
# Epoch 1405 loss: 24.307
# Epoch 1406 loss: 22.318
# Epoch 1407 loss: 24.499
# Epoch 1408 loss: 22.900
# Epoch 1409 loss: 24.446
# Epoch 1410 loss: 24.287
# Epoch 1411 loss: 24.312
# Epoch 1412 loss: 23.630
# Epoch 1413 loss: 24.835
# Epoch 1414 loss: 22.077
# Epoch 1415 loss: 23.879
# Epoch 1416 loss: 24.882
# Epoch 1417 loss: 25.676
# Epoch 1418 loss: 24.507
# Epoch 1419 loss: 23.170
# Epoch 1420 loss: 23.062
# Epoch 1421 loss: 26.217
# Epoch 1422 loss: 22.200
# Epoch 1423 loss: 22.809
# Epoch 1424 loss: 22.196
# Epoch 1425 loss: 15.062
# Epoch 1426 loss: 23.182
# Epoch 1427 loss: 25.792
# Epoch 1428 loss: 22.842
# Epoch 1429 loss: 20.791
# Epoch 1430 loss: 24.290
# Epoch 1431 loss: 24.158
# Epoch 1432 loss: 23.494
# Epoch 1433 loss: 22.573
# Epoch 1434 loss: 24.811
# Epoch 1435 loss: 23.345
# Epoch 1436 loss: 26.346
# Epoch 1437 loss: 24.827
# Epoch 1438 loss: 26.009
# Epoch 1439 loss: 23.571
# Epoch 1440 loss: 24.793
# Epoch 1441 loss: 27.375
# Epoch 1442 loss: 23.796
# Epoch 1443 loss: 21.859
# Epoch 1444 loss: 25.395
# Epoch 1445 loss: 23.987
# Epoch 1446 loss: 23.522
# Epoch 1447 loss: 21.678
# Epoch 1448 loss: 23.227
# Epoch 1449 loss: 21.686
# Epoch 1450 loss: 23.135
# Epoch 1451 loss: 24.500
# Epoch 1452 loss: 23.732
# Epoch 1453 loss: 22.968
# Epoch 1454 loss: 20.995
# Epoch 1455 loss: 23.495
# Epoch 1456 loss: 23.546
# Epoch 1457 loss: 22.995
# Epoch 1458 loss: 25.058
# Epoch 1459 loss: 15.433
# Epoch 1460 loss: 22.122
# Epoch 1461 loss: 23.926
# Epoch 1462 loss: 16.165
# Epoch 1463 loss: 25.262
# Epoch 1464 loss: 24.625
# Epoch 1465 loss: 22.639
# Epoch 1466 loss: 24.441
# Epoch 1467 loss: 25.155
# Epoch 1468 loss: 23.024
# Epoch 1469 loss: 23.304
# Epoch 1470 loss: 24.043
# Epoch 1471 loss: 24.486
# Epoch 1472 loss: 24.259
# Epoch 1473 loss: 17.869
# Epoch 1474 loss: 24.544
# Epoch 1475 loss: 23.934
# Epoch 1476 loss: 22.786
# Epoch 1477 loss: 23.758
# Epoch 1478 loss: 24.401
# Epoch 1479 loss: 15.516
# Epoch 1480 loss: 14.287
# Epoch 1481 loss: 24.634
# Epoch 1482 loss: 26.601
# Epoch 1483 loss: 26.721
# Epoch 1484 loss: 24.011
# Epoch 1485 loss: 21.827
# Epoch 1486 loss: 23.192
# Epoch 1487 loss: 22.984
# Epoch 1488 loss: 23.911
# Epoch 1489 loss: 23.395
# Epoch 1490 loss: 21.236
# Epoch 1491 loss: 23.895
# Epoch 1492 loss: 25.526
# Epoch 1493 loss: 24.038
# Epoch 1494 loss: 24.068
# Epoch 1495 loss: 22.682
# Epoch 1496 loss: 26.777
# Epoch 1497 loss: 19.731
# Epoch 1498 loss: 22.818
# Epoch 1499 loss: 24.444
# Epoch 1500 loss: 26.683
# Epoch 1501 loss: 27.582
# Epoch 1502 loss: 16.547
# Epoch 1503 loss: 24.102
# Epoch 1504 loss: 27.790
# Epoch 1505 loss: 31.841
# Epoch 1506 loss: 18.669
# Epoch 1507 loss: 22.365
# Epoch 1508 loss: 24.378
# Epoch 1509 loss: 24.658
# Epoch 1510 loss: 22.149
# Epoch 1511 loss: 23.612
# Epoch 1512 loss: 16.055
# Epoch 1513 loss: 22.625
# Epoch 1514 loss: 23.893
# Epoch 1515 loss: 22.451
# Epoch 1516 loss: 23.865
# Epoch 1517 loss: 24.425
# Epoch 1518 loss: 23.361
# Epoch 1519 loss: 23.039
# Epoch 1520 loss: 23.512
# Epoch 1521 loss: 24.138
# Epoch 1522 loss: 23.660
# Epoch 1523 loss: 23.433
# Epoch 1524 loss: 23.234
# Epoch 1525 loss: 21.565
# Epoch 1526 loss: 22.492
# Epoch 1527 loss: 22.614
# Epoch 1528 loss: 23.870
# Epoch 1529 loss: 22.888
# Epoch 1530 loss: 23.546
# Epoch 1531 loss: 24.109
# Epoch 1532 loss: 19.105
# Epoch 1533 loss: 21.838
# Epoch 1534 loss: 22.400
# Epoch 1535 loss: 22.196
# Epoch 1536 loss: 22.972
# Epoch 1537 loss: 24.413
# Epoch 1538 loss: 25.407
# Epoch 1539 loss: 25.433
# Epoch 1540 loss: 23.100
# Epoch 1541 loss: 23.069
# Epoch 1542 loss: 17.646
# Epoch 1543 loss: 22.046
# Epoch 1544 loss: 23.550
# Epoch 1545 loss: 24.413
# Epoch 1546 loss: 24.317
# Epoch 1547 loss: 23.604
# Epoch 1548 loss: 22.921
# Epoch 1549 loss: 23.290
# Epoch 1550 loss: 15.732
# Epoch 1551 loss: 23.728
# Epoch 1552 loss: 15.986
# Epoch 1553 loss: 23.870
# Epoch 1554 loss: 23.092
# Epoch 1555 loss: 24.220
# Epoch 1556 loss: 24.092
# Epoch 1557 loss: 25.082
# Epoch 1558 loss: 23.021
# Epoch 1559 loss: 24.260
# Epoch 1560 loss: 21.299
# Epoch 1561 loss: 23.642
# Epoch 1562 loss: 21.873
# Epoch 1563 loss: 22.839
# Epoch 1564 loss: 23.770
# Epoch 1565 loss: 21.313
# Epoch 1566 loss: 21.798
# Epoch 1567 loss: 22.033
# Epoch 1568 loss: 22.764
# Epoch 1569 loss: 24.227
# Epoch 1570 loss: 24.464
# Epoch 1571 loss: 24.561
# Epoch 1572 loss: 24.363
# Epoch 1573 loss: 22.599
# Epoch 1574 loss: 23.386
# Epoch 1575 loss: 22.989
# Epoch 1576 loss: 21.783
# Epoch 1577 loss: 16.043
# Epoch 1578 loss: 14.900
# Epoch 1579 loss: 23.812
# Epoch 1580 loss: 23.416
# Epoch 1581 loss: 16.007
# Epoch 1582 loss: 23.716
# Epoch 1583 loss: 24.747
# Epoch 1584 loss: 23.687
# Epoch 1585 loss: 21.338
# Epoch 1586 loss: 22.584
# Epoch 1587 loss: 22.528
# Epoch 1588 loss: 21.300
# Epoch 1589 loss: 23.762
# Epoch 1590 loss: 21.801
# Epoch 1591 loss: 23.682
# Epoch 1592 loss: 22.398
# Epoch 1593 loss: 21.680
# Epoch 1594 loss: 23.492
# Epoch 1595 loss: 17.192
# Epoch 1596 loss: 25.150
# Epoch 1597 loss: 25.378
# Epoch 1598 loss: 21.408
# Epoch 1599 loss: 22.934
# Epoch 1600 loss: 24.009
# Epoch 1601 loss: 24.949
# Epoch 1602 loss: 16.545
# Epoch 1603 loss: 22.514
# Epoch 1604 loss: 23.660
# Epoch 1605 loss: 15.773
# Epoch 1606 loss: 24.075
# Epoch 1607 loss: 23.479
# Epoch 1608 loss: 22.522
# Epoch 1609 loss: 22.832
# Epoch 1610 loss: 17.442
# Epoch 1611 loss: 21.997
# Epoch 1612 loss: 26.356
# Epoch 1613 loss: 26.120
# Epoch 1614 loss: 23.486
# Epoch 1615 loss: 22.859
# Epoch 1616 loss: 21.981
# Epoch 1617 loss: 14.917
# Epoch 1618 loss: 24.892
# Epoch 1619 loss: 24.125
# Epoch 1620 loss: 23.537
# Epoch 1621 loss: 18.172
# Epoch 1622 loss: 21.332
# Epoch 1623 loss: 23.381
# Epoch 1624 loss: 24.567
# Epoch 1625 loss: 22.885
# Epoch 1626 loss: 23.221
# Epoch 1627 loss: 23.735
# Epoch 1628 loss: 23.009
# Epoch 1629 loss: 24.160
# Epoch 1630 loss: 23.392
# Epoch 1631 loss: 22.072
# Epoch 1632 loss: 21.978
# Epoch 1633 loss: 23.162
# Epoch 1634 loss: 24.329
# Epoch 1635 loss: 17.115
# Epoch 1636 loss: 23.570
# Epoch 1637 loss: 16.771
# Epoch 1638 loss: 24.713
# Epoch 1639 loss: 29.442
# Epoch 1640 loss: 19.270
# Epoch 1641 loss: 27.218
# Epoch 1642 loss: 22.925
# Epoch 1643 loss: 23.069
# Epoch 1644 loss: 24.688
# Epoch 1645 loss: 24.585
# Epoch 1646 loss: 25.616
# Epoch 1647 loss: 14.521
# Epoch 1648 loss: 15.062
# Epoch 1649 loss: 24.051
# Epoch 1650 loss: 23.911
# Epoch 1651 loss: 23.546
# Epoch 1652 loss: 25.826
# Epoch 1653 loss: 23.994
# Epoch 1654 loss: 23.319
# Epoch 1655 loss: 16.562
# Epoch 1656 loss: 23.312
# Epoch 1657 loss: 22.898
# Epoch 1658 loss: 23.064
# Epoch 1659 loss: 22.219
# Epoch 1660 loss: 23.288
# Epoch 1661 loss: 22.737
# Epoch 1662 loss: 22.227
# Epoch 1663 loss: 25.552
# Epoch 1664 loss: 22.877
# Epoch 1665 loss: 23.935
# Epoch 1666 loss: 19.697
# Epoch 1667 loss: 24.964
# Epoch 1668 loss: 24.528
# Epoch 1669 loss: 24.372
# Epoch 1670 loss: 16.459
# Epoch 1671 loss: 21.950
# Epoch 1672 loss: 23.273
# Epoch 1673 loss: 23.039
# Epoch 1674 loss: 22.006
# Epoch 1675 loss: 24.383
# Epoch 1676 loss: 22.692
# Epoch 1677 loss: 17.628
# Epoch 1678 loss: 23.322
# Epoch 1679 loss: 23.787
# Epoch 1680 loss: 22.950
# Epoch 1681 loss: 19.576
# Epoch 1682 loss: 22.759
# Epoch 1683 loss: 22.859
# Epoch 1684 loss: 24.011
# Epoch 1685 loss: 21.388
# Epoch 1686 loss: 21.953
# Epoch 1687 loss: 14.427
# Epoch 1688 loss: 26.710
# Epoch 1689 loss: 25.458
# Epoch 1690 loss: 22.654
# Epoch 1691 loss: 16.193
# Epoch 1692 loss: 21.612
# Epoch 1693 loss: 23.423
# Epoch 1694 loss: 21.370
# Epoch 1695 loss: 22.518
# Epoch 1696 loss: 13.810
# Epoch 1697 loss: 21.740
# Epoch 1698 loss: 22.200
# Epoch 1699 loss: 25.463
# Epoch 1700 loss: 23.628
# Epoch 1701 loss: 22.628
# Epoch 1702 loss: 25.963
# Epoch 1703 loss: 24.931
# Epoch 1704 loss: 22.990
# Epoch 1705 loss: 23.215
# Epoch 1706 loss: 23.114
# Epoch 1707 loss: 15.670
# Epoch 1708 loss: 24.217
# Epoch 1709 loss: 22.902
# Epoch 1710 loss: 25.093
# Epoch 1711 loss: 21.019
# Epoch 1712 loss: 24.063
# Epoch 1713 loss: 21.596
# Epoch 1714 loss: 22.324
# Epoch 1715 loss: 27.340
# Epoch 1716 loss: 20.576
# Epoch 1717 loss: 22.592
# Epoch 1718 loss: 21.043
# Epoch 1719 loss: 22.738
# Epoch 1720 loss: 23.484
# Epoch 1721 loss: 23.929
# Epoch 1722 loss: 22.612
# Epoch 1723 loss: 22.991
# Epoch 1724 loss: 23.516
# Epoch 1725 loss: 23.876
# Epoch 1726 loss: 16.288
# Epoch 1727 loss: 21.973
# Epoch 1728 loss: 24.641
# Epoch 1729 loss: 31.849
# Epoch 1730 loss: 16.353
# Epoch 1731 loss: 22.287
# Epoch 1732 loss: 22.766
# Epoch 1733 loss: 26.408
# Epoch 1734 loss: 23.916
# Epoch 1735 loss: 23.392
# Epoch 1736 loss: 23.984
# Epoch 1737 loss: 24.994
# Epoch 1738 loss: 26.854
# Epoch 1739 loss: 23.489
# Epoch 1740 loss: 20.682
# Epoch 1741 loss: 24.971
# Epoch 1742 loss: 23.021
# Epoch 1743 loss: 20.375
# Epoch 1744 loss: 22.552
# Epoch 1745 loss: 24.717
# Epoch 1746 loss: 23.497
# Epoch 1747 loss: 22.011
# Epoch 1748 loss: 24.815
# Epoch 1749 loss: 21.587
# Epoch 1750 loss: 24.748
# Epoch 1751 loss: 23.634
# Epoch 1752 loss: 16.676
# Epoch 1753 loss: 23.587
# Epoch 1754 loss: 21.106
# Epoch 1755 loss: 23.830
# Epoch 1756 loss: 22.954
# Epoch 1757 loss: 15.545
# Epoch 1758 loss: 23.377
# Epoch 1759 loss: 23.291
# Epoch 1760 loss: 14.508
# Epoch 1761 loss: 23.393
# Epoch 1762 loss: 15.542
# Epoch 1763 loss: 24.848
# Epoch 1764 loss: 25.353
# Epoch 1765 loss: 21.781
# Epoch 1766 loss: 23.112
# Epoch 1767 loss: 23.458
# Epoch 1768 loss: 20.941
# Epoch 1769 loss: 22.936
# Epoch 1770 loss: 14.782
# Epoch 1771 loss: 23.148
# Epoch 1772 loss: 22.221
# Epoch 1773 loss: 17.587
# Epoch 1774 loss: 22.375
# Epoch 1775 loss: 23.963
# Epoch 1776 loss: 22.631
# Epoch 1777 loss: 24.929
# Epoch 1778 loss: 23.771
# Epoch 1779 loss: 23.136
# Epoch 1780 loss: 19.890
# Epoch 1781 loss: 21.680
# Epoch 1782 loss: 22.556
# Epoch 1783 loss: 21.119
# Epoch 1784 loss: 21.171
# Epoch 1785 loss: 23.131
# Epoch 1786 loss: 24.300
# Epoch 1787 loss: 22.562
# Epoch 1788 loss: 21.903
# Epoch 1789 loss: 20.971
# Epoch 1790 loss: 24.462
# Epoch 1791 loss: 23.311
# Epoch 1792 loss: 22.138
# Epoch 1793 loss: 22.692
# Epoch 1794 loss: 22.773
# Epoch 1795 loss: 24.358
# Epoch 1796 loss: 22.118
# Epoch 1797 loss: 23.605
# Epoch 1798 loss: 23.634
# Epoch 1799 loss: 20.405
# Epoch 1800 loss: 22.284
# Epoch 1801 loss: 21.559
# Epoch 1802 loss: 22.190
# Epoch 1803 loss: 13.796
# Epoch 1804 loss: 21.017
# Epoch 1805 loss: 22.731
# Epoch 1806 loss: 22.512
# Epoch 1807 loss: 21.217
# Epoch 1808 loss: 15.022
# Epoch 1809 loss: 22.609
# Epoch 1810 loss: 21.513
# Epoch 1811 loss: 24.443
# Epoch 1812 loss: 21.504
# Epoch 1813 loss: 23.510
# Epoch 1814 loss: 21.930
# Epoch 1815 loss: 21.579
# Epoch 1816 loss: 22.272
# Epoch 1817 loss: 23.100
# Epoch 1818 loss: 23.733
# Epoch 1819 loss: 23.501
# Epoch 1820 loss: 22.774
# Epoch 1821 loss: 25.172
# Epoch 1822 loss: 20.909
# Epoch 1823 loss: 21.969
# Epoch 1824 loss: 22.472
# Epoch 1825 loss: 22.989
# Epoch 1826 loss: 20.733
# Epoch 1827 loss: 20.000
# Epoch 1828 loss: 24.686
# Epoch 1829 loss: 25.990
# Epoch 1830 loss: 22.368
# Epoch 1831 loss: 23.063
# Epoch 1832 loss: 24.002
# Epoch 1833 loss: 23.519
# Epoch 1834 loss: 22.961
# Epoch 1835 loss: 22.061
# Epoch 1836 loss: 23.272
# Epoch 1837 loss: 20.110
# Epoch 1838 loss: 22.450
# Epoch 1839 loss: 23.482
# Epoch 1840 loss: 22.259
# Epoch 1841 loss: 23.190
# Epoch 1842 loss: 23.187
# Epoch 1843 loss: 24.479
# Epoch 1844 loss: 22.210
# Epoch 1845 loss: 16.900
# Epoch 1846 loss: 22.280
# Epoch 1847 loss: 24.939
# Epoch 1848 loss: 22.052
# Epoch 1849 loss: 23.701
# Epoch 1850 loss: 21.017
# Epoch 1851 loss: 24.013
# Epoch 1852 loss: 21.681
# Epoch 1853 loss: 23.670
# Epoch 1854 loss: 21.856
# Epoch 1855 loss: 23.153
# Epoch 1856 loss: 22.824
# Epoch 1857 loss: 21.721
# Epoch 1858 loss: 21.094
# Epoch 1859 loss: 14.472
# Epoch 1860 loss: 21.339
# Epoch 1861 loss: 21.435
# Epoch 1862 loss: 22.478
# Epoch 1863 loss: 20.960
# Epoch 1864 loss: 21.799
# Epoch 1865 loss: 17.076
# Epoch 1866 loss: 21.133
# Epoch 1867 loss: 22.751
# Epoch 1868 loss: 23.215
# Epoch 1869 loss: 23.970
# Epoch 1870 loss: 21.740
# Epoch 1871 loss: 21.151
# Epoch 1872 loss: 22.215
# Epoch 1873 loss: 24.716
# Epoch 1874 loss: 17.787
# Epoch 1875 loss: 22.235
# Epoch 1876 loss: 25.279
# Epoch 1877 loss: 23.269
# Epoch 1878 loss: 21.736
# Epoch 1879 loss: 14.622
# Epoch 1880 loss: 24.294
# Epoch 1881 loss: 20.941
# Epoch 1882 loss: 22.364
# Epoch 1883 loss: 20.162
# Epoch 1884 loss: 21.913
# Epoch 1885 loss: 23.341
# Epoch 1886 loss: 23.051
# Epoch 1887 loss: 21.530
# Epoch 1888 loss: 23.179
# Epoch 1889 loss: 20.380
# Epoch 1890 loss: 14.570
# Epoch 1891 loss: 22.365
# Epoch 1892 loss: 24.513
# Epoch 1893 loss: 22.761
# Epoch 1894 loss: 22.251
# Epoch 1895 loss: 22.365
# Epoch 1896 loss: 23.934
# Epoch 1897 loss: 23.149
# Epoch 1898 loss: 22.147
# Epoch 1899 loss: 22.514
# Epoch 1900 loss: 14.002
# Epoch 1901 loss: 21.696
# Epoch 1902 loss: 22.524
# Epoch 1903 loss: 21.944
# Epoch 1904 loss: 22.928
# Epoch 1905 loss: 24.067
# Epoch 1906 loss: 16.456
# Epoch 1907 loss: 23.015
# Epoch 1908 loss: 19.328
# Epoch 1909 loss: 21.572
# Epoch 1910 loss: 14.970
# Epoch 1911 loss: 16.400
# Epoch 1912 loss: 22.203
# Epoch 1913 loss: 21.819
# Epoch 1914 loss: 20.750
# Epoch 1915 loss: 22.389
# Epoch 1916 loss: 22.572
# Epoch 1917 loss: 24.643
# Epoch 1918 loss: 22.629
# Epoch 1919 loss: 24.333
# Epoch 1920 loss: 22.881
# Epoch 1921 loss: 22.397
# Epoch 1922 loss: 21.925
# Epoch 1923 loss: 23.913
# Epoch 1924 loss: 22.921
# Epoch 1925 loss: 22.131
# Epoch 1926 loss: 14.678
# Epoch 1927 loss: 20.713
# Epoch 1928 loss: 22.864
# Epoch 1929 loss: 22.919
# Epoch 1930 loss: 19.308
# Epoch 1931 loss: 20.827
# Epoch 1932 loss: 22.428
# Epoch 1933 loss: 22.272
# Epoch 1934 loss: 21.584
# Epoch 1935 loss: 22.832
# Epoch 1936 loss: 21.871
# Epoch 1937 loss: 20.533
# Epoch 1938 loss: 20.777
# Epoch 1939 loss: 22.965
# Epoch 1940 loss: 19.527
# Epoch 1941 loss: 23.514
# Epoch 1942 loss: 23.279
# Epoch 1943 loss: 21.780
# Epoch 1944 loss: 23.053
# Epoch 1945 loss: 26.810
# Epoch 1946 loss: 24.141
# Epoch 1947 loss: 16.919
# Epoch 1948 loss: 25.315
# Epoch 1949 loss: 24.083
# Epoch 1950 loss: 20.961
# Epoch 1951 loss: 21.187
# Epoch 1952 loss: 21.757
# Epoch 1953 loss: 14.624
# Epoch 1954 loss: 20.000
# Epoch 1955 loss: 23.701
# Epoch 1956 loss: 29.337
# Epoch 1957 loss: 29.387
# Epoch 1958 loss: 23.850
# Epoch 1959 loss: 23.079
# Epoch 1960 loss: 22.200
# Epoch 1961 loss: 25.882
# Epoch 1962 loss: 22.714
# Epoch 1963 loss: 21.052
# Epoch 1964 loss: 22.987
# Epoch 1965 loss: 23.579
# Epoch 1966 loss: 25.221
# Epoch 1967 loss: 22.802
# Epoch 1968 loss: 22.901
# Epoch 1969 loss: 21.754
# Epoch 1970 loss: 25.330
# Epoch 1971 loss: 24.971
# Epoch 1972 loss: 22.928
# Epoch 1973 loss: 24.014
# Epoch 1974 loss: 28.383
# Epoch 1975 loss: 24.562
# Epoch 1976 loss: 22.590
# Epoch 1977 loss: 21.740
# Epoch 1978 loss: 24.024
# Epoch 1979 loss: 24.813
# Epoch 1980 loss: 18.383
# Epoch 1981 loss: 13.418
# Epoch 1982 loss: 23.455
# Epoch 1983 loss: 21.832
# Epoch 1984 loss: 16.894
# Epoch 1985 loss: 21.354
# Epoch 1986 loss: 21.390
# Epoch 1987 loss: 21.568
# Epoch 1988 loss: 22.351
# Epoch 1989 loss: 20.646
# Epoch 1990 loss: 22.899
# Epoch 1991 loss: 16.552
# Epoch 1992 loss: 22.231
# Epoch 1993 loss: 15.640
# Epoch 1994 loss: 14.045
# Epoch 1995 loss: 16.075
# Epoch 1996 loss: 18.370
# Epoch 1997 loss: 24.809
# Epoch 1998 loss: 22.297
# Epoch 1999 loss: 20.305
# Epoch 2000 loss: 20.646

# %%
# example prediction
joint_model.eval()

ytest_gt = ytest.astype('category').cat.codes

liptest_tensor = torch.tensor(test_lip.T.values, dtype=torch.float32)
protest_tensor = torch.tensor(test_pro.T.values, dtype=torch.float32)
metabtest_tensor = torch.tensor(test_metab.T.values, dtype=torch.float32)

with torch.inference_mode():
    yhat, poe_dist, yhats, dists = joint_model([liptest_tensor, metabtest_tensor, protest_tensor])

ypred = yhat.argmax(dim=1).numpy()

(ypred == ytest_gt.to_numpy()).mean()
# Out:
# 1.0

# %%
confusion_matrix(ytest_gt, ypred)
# Out:
# array([[6, 0],
#        [0, 6]])

# %%
# order is lip metab pro
(
    (yhats[0].argmax(dim=1).numpy() == ytest_gt.to_numpy()).mean(),
    (yhats[1].argmax(dim=1).numpy() == ytest_gt.to_numpy()).mean(),
    (yhats[2].argmax(dim=1).numpy() == ytest_gt.to_numpy()).mean()
)
# Out:
# (0.9166666666666666, 1.0, 1.0)

# %%
pred_lip = yhats[0].argmax(dim=1).numpy()
pred_pro = yhats[1].argmax(dim=1).numpy()
pred_metab = yhats[2].argmax(dim=1).numpy()

(
    confusion_matrix(ytest_gt.to_numpy(), pred_lip),
    confusion_matrix(ytest_gt.to_numpy(), pred_pro),
    confusion_matrix(ytest_gt.to_numpy(), pred_metab)
)
# Out:
# (array([[6, 0],
#         [4, 2]]),
#  array([[6, 0],
#         [3, 3]]),
#  array([[4, 2],
#         [2, 4]]))

# %% [markdown]
# # Variable Importance

# %% [markdown]
# ## Gradient analysis
#
# As a first pass for variable importance, I simply take the gradient of input input w.r.t. the predicted output probability of the positive class.  Essentially I am trying to determine which input biomolecules are important for the ability of the model to predict the positive class.

# %%
# get a single positive example (-1, the last example is positive)
liptest_pos = torch.clone(liptest_tensor[-1].unsqueeze(0))
protest_pos = torch.clone(protest_tensor[-1].unsqueeze(0))
metabtest_pos = torch.clone(metabtest_tensor[-1].unsqueeze(0))

liptest_pos.requires_grad = True
protest_pos.requires_grad = True
metabtest_pos.requires_grad = True

yhat, poe_dist, yhats, dists = joint_model([liptest_pos, metabtest_pos, protest_pos])

# %%
yhat[0,1].backward()

# %%
# get the gradients and multiply by the input
# (
# liptest_pos.grad.abs().argsort()[:,:10],
# protest_pos.grad.abs().argsort()[:,:10],
# metabtest_pos.grad.abs().argsort()[:,:10]
# )

liptest_scores = liptest_pos.grad * liptest_pos
protest_scores = protest_pos.grad * protest_pos
metabtest_scores = metabtest_pos.grad * metabtest_pos

(
liptest_scores.argsort()[:,:10],
protest_scores.argsort()[:,:10],
metabtest_scores.argsort()[:,:10]
)
# Out:
# (tensor([[243, 236,   3,  35, 177, 205,  23, 230, 226, 246]]),
#  tensor([[ 430,  311,  649, 1398, 1441,   11,  889, 1101, 1397, 1391]]),
#  tensor([[ 62,  75, 108, 124,  10,  17,  84, 107, 106,  41]]))

# %%
liptest_pos = torch.clone(liptest_tensor[ytest_gt.to_numpy() == 1])
protest_pos = torch.clone(protest_tensor[ytest_gt.to_numpy() == 1])
metabtest_pos = torch.clone(metabtest_tensor[ytest_gt.to_numpy() == 1])

liptest_pos.requires_grad = True
protest_pos.requires_grad = True
metabtest_pos.requires_grad = True

yhat, poe_dist, yhats, dists = joint_model([liptest_pos, metabtest_pos, protest_pos])

# %%
yhat[:,1].mean().backward()

# %%
# (
# liptest_pos.grad.abs().sum(axis=0).argsort()[:10],
# protest_pos.grad.abs().sum(axis=0).argsort()[:10],
# metabtest_pos.grad.abs().sum(axis=0).argsort()[:10]
# )

liptest_scores = liptest_pos.grad * liptest_pos
protest_scores = protest_pos.grad * protest_pos
metabtest_scores = metabtest_pos.grad * metabtest_pos

(
liptest_scores.sum(axis = 0).argsort()[:10],
protest_scores.sum(axis = 0).argsort()[:10],
metabtest_scores.sum(axis = 0).argsort()[:10]
)
# Out:
# (tensor([  3, 240, 123, 204,   4,   8,   2,   1, 243, 140]),
#  tensor([1189, 2190, 1188, 2962,   61,   46, 2601, 1349, 2216,   91]),
#  tensor([  4, 109, 119, 130,  45,  62, 104,  16, 112,  52]))

# %% [markdown]
# # Integrated Gradients
#
# Integrated gradients overcome the problem of non-sensitivity of gradients methods, see https://arxiv.org/pdf/1703.01365.pdf for an explanation.
#
# As described in the paper, we start at some 'non-informative' baseline, and move linearly towards our actual input, taking the gradient at each step and accumulating.  At the end we divide by the number of steps to get the average gradient, which approximates and integral.  This is the integrated gradient.

# %%
liptest_pos = torch.clone(liptest_tensor[ytest_gt.to_numpy() == 1])
protest_pos = torch.clone(protest_tensor[ytest_gt.to_numpy() == 1])
metabtest_pos = torch.clone(metabtest_tensor[ytest_gt.to_numpy() == 1])

# %%
def integrated_grads(views, baselines, model, n_steps = 100, class_idx = 1):
    grads = [torch.zeros_like(v) for v in baselines]
    for i in range(1, n_steps + 1):
        tmp = [torch.clone(b) for b in baselines]
        tmp = [b + i * (vtest - b) for b, vtest in zip(tmp, views)]
        tmp = [b.requires_grad_() for b in tmp]
        yhat, poe_dist, yhats, dists = model(tmp)
        yhat[:,class_idx].mean().backward()
        grads = [g + b.grad for g, b in zip(grads, tmp)]

    return [g * (v - b) / n_steps for g, b, v in zip(grads, baselines, views)]

# %%
# move along the baseline (noise) to input, take the gradient at each step, and accumulate.  Divide at the end to form an average.
# lip_baseline = torch.randn_like(liptest_pos, requires_grad = True)*liptest_pos.std() + liptest_pos.mean()
# pro_baseline = torch.randn_like(protest_pos, requires_grad = True)*protest_pos.std() + protest_pos.mean()
# metab_baseline = torch.randn_like(metabtest_pos, requires_grad = True)*metabtest_pos.std() + metabtest_pos.mean()

# grad_lip = torch.zeros_like(lip_baseline)
# grad_pro = torch.zeros_like(pro_baseline)
# grad_metab = torch.zeros_like(metab_baseline)

# n_steps = 100

# for i in range(1, n_steps + 1):
#     tmp_lip = torch.clone(lip_baseline)
#     tmp_pro = torch.clone(pro_baseline)
#     tmp_metab = torch.clone(metab_baseline)

#     tmp_lip = tmp_lip + i * (liptest_pos - tmp_lip)/n_steps
#     tmp_pro = tmp_pro + i * (protest_pos - tmp_pro)/n_steps
#     tmp_metab = tmp_metab + i * (metabtest_pos - tmp_metab)/n_steps

#     tmp_lip.requires_grad = True
#     tmp_pro.requires_grad = True
#     tmp_metab.requires_grad = True

#     yhat, poe_dist, yhats, dists = joint_model([tmp_lip, tmp_metab, tmp_pro])

#     yhat[:,1].mean().backward()

#     grad_lip += tmp_lip.grad
#     grad_pro += tmp_pro.grad
#     grad_metab += tmp_metab.grad

# %%
# baseline is normal noise with mean and std from the data
# vary these to see if we get different results...
# scree plot
# lip_baseline = torch.randn_like(liptest_pos)*liptest_pos.std().numpy() + liptest_pos.mean().numpy()
# pro_baseline = torch.randn_like(protest_pos)*protest_pos.std().numpy() + protest_pos.mean().numpy()
# metab_baseline = torch.randn_like(metabtest_pos)*metabtest_pos.std().numpy() + metabtest_pos.mean().numpy()

lip_baseline = -torch.rand_like(liptest_pos)/2# *2*liptest_pos.std().numpy() + liptest_pos.mean().numpy()
pro_baseline = -torch.rand_like(protest_pos)/2# *2*protest_pos.std().numpy() + protest_pos.mean().numpy()
metab_baseline = -torch.rand_like(metabtest_pos)/2# *2*metabtest_pos.std().numpy() + metabtest_pos.mean().numpy()

# %%
joint_model.eval()

lip_int_scores, metab_int_scores, pro_int_scores = integrated_grads(
    [liptest_pos, metabtest_pos, protest_pos], 
    [lip_baseline, metab_baseline, pro_baseline], 
    joint_model, n_steps = 100, class_idx = 1
)

# %%
top_lip = lip_int_scores.sum(axis = 0).argsort()[:10]
top_pro = pro_int_scores.sum(axis = 0).argsort()[:10]
top_metab = metab_int_scores.sum(axis = 0).argsort()[:10]

(
top_lip,
top_pro,
top_metab
)
# Out:
# (tensor([  3, 240,  95,   4, 123, 204, 236,   0,   5,   6]),
#  tensor([ 482, 1609, 1616, 1615, 1167, 1601, 1253, 1603, 1671,  348]),
#  tensor([ 39,   2,  34,  62,   9,  83, 114,  46,  73,  54]))

# %%
sorted_lip_scores = sorted(lip_int_scores.sum(axis = 0).numpy(), reverse = True)
sorted_pro_scores = sorted(pro_int_scores.sum(axis = 0).numpy(), reverse = True)
sorted_metab_scores = sorted(metab_int_scores.sum(axis = 0).numpy(), reverse = True)

lipids_out = pd.DataFrame({
    "Lipids":test_lip.iloc[lip_int_scores.sum(axis = 0).argsort().numpy(), :].index,
    "Lipid_Scores": sorted_lip_scores
})

proteins_out = pd.DataFrame({
    "Proteins": test_pro.iloc[pro_int_scores.sum(axis = 0).argsort().numpy(), :].index,
    "Protein_Scores": sorted_pro_scores
})

metabolites_out = pd.DataFrame({
    "Metabolites": test_metab.iloc[metab_int_scores.sum(axis = 0).argsort().numpy(), :].index,
    "Metabolite_Scores": sorted_metab_scores
})

# lipids_out.to_csv("./output/lipids_ICL104share_igrads.csv")
# proteins_out.to_csv("./output/proteins_ICL104share_igrads.csv")
# metabolites_out.to_csv("./output/metabolites_ICL104share_igrads.csv")

# %%
imv_proteins = proteins_out['Proteins']
imv_metabs = metabolites_out['Metabolites']

# %%
anova_proteins = pro_anova[pro_anova['P_value_A_Cal04_vs_Mock'] < 0.05]["Protein"]
anova_metabs = metab_anova[metab_anova['P_value_A_Cal04_vs_Mock'] < 0.05]["Metabolite"]

# %%
imv_metabs.iloc[0:len(anova_metabs)].isin(anova_metabs).sum()
# Out:
# 4

# %%
len(imv_proteins)
# Out:
# 1781

# %%
imv_proteins.iloc[0:1700].isin(anova_proteins).sum()
# Out:
# 225

# %%
imv_metabs
# Out:
# 0                 Unknown 066
# 1                L-methionine
# 2        D-ribose-5-phosphate
# 3          aminomalnoic acid*
# 4      3-phosphoglyceric acid
#                 ...
# 128               Unknown 036
# 129               Unknown 004
# 130               Unknown 037
# 131             caprylic acid
# 132                putrescine
# Name: Metabolites, Length: 133, dtype: object

# %%
anova_metabs[anova_metabs.isin(imv_metabs)].shape
# Out:
# (25,)

# %%
len(anova_proteins)
# Out:
# 416

# %%
# get the intersect between imv_proteins and anova_proteins
imv_proteins[imv_proteins.isin(anova_proteins)]
# Out:
# 226

# %%
(
test_lip.iloc[top_lip.numpy(), :].index,
test_pro.iloc[top_pro.numpy(), :].index,
test_metab.iloc[top_metab.numpy(), :].index
)
# Out:
# (Index(['PC(O-20:0/18:1);PC(O-16:0/22:1);PC(O-18:0/20:1)', 'TG(58:3)',
#         'Cer(d18:0/24:0)', 'Cer(d18:0/24:1)', 'Cer(d18:0/18:0)',
#         'Cer(d18:0/16:0)_B', 'CerH2O(d18:0/16:0)_B', 'PE(20:4/0:0)',
#         'CerH2O(d18:1/18:0)', 'GalCer(d18:2/16:0)'],
#        dtype='object', name='LIPID'),
#  Index(['H1N1_CA04_NS1', 'H1N1_CA04_NP', 'PNPT1_HUMAN', 'RRP8_HUMAN',
#         'SYCC_HUMAN', 'RIN1_HUMAN', '1B48_HUMAN', '5NT3A_HUMAN', 'PPBN_HUMAN',
#         'STAT1_HUMAN'],
#        dtype='object', name='REFERENCE'),
#  Index(['urea', 'glyceric acid', 'carbonate ion', 'L-pyroglutamic acid',
#         'L-alanine', 'aminomalnoic acid*', 'levoglucosan*',
#         'D-ribulose-5-phosphate', 'thymine', 'Unknown 008'],
#        dtype='object', name='METABOLITE'))

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(3, 1, figsize = (10, 12))
axs[0].plot(sorted(lip_int_scores.sum(axis = 0).numpy(), reverse = True))
axs[1].plot(sorted(pro_int_scores.sum(axis = 0).numpy(), reverse = True))
axs[2].plot(sorted(metab_int_scores.sum(axis = 0).numpy(), reverse = True))

axs[0].set_title('Lipid')
axs[1].set_title('Protein')
axs[2].set_title('Metabolite')

plt.tight_layout()

# %%
lip_ranks = {}
pro_ranks = {}
metab_ranks = {}

for k in range(50):
    lip_baseline = -torch.rand_like(liptest_pos)/2# *2*liptest_pos.std().numpy() + liptest_pos.mean().numpy()
    pro_baseline = -torch.rand_like(protest_pos)/2# *2*protest_pos.std().numpy() + protest_pos.mean().numpy()
    metab_baseline = -torch.rand_like(metabtest_pos)/2# *2*metabtest_pos.std().numpy() + metabtest_pos.mean().numpy()

    lip_int_scores, metab_int_scores, pro_int_scores = integrated_grads(
        [liptest_pos, metabtest_pos, protest_pos], 
        [lip_baseline, metab_baseline, pro_baseline], 
        joint_model, n_steps = 100, class_idx = 1
    )

    lip_argsort = lip_int_scores.sum(axis = 0).argsort()
    pro_argsort = pro_int_scores.sum(axis = 0).argsort()
    metab_argsort = metab_int_scores.sum(axis = 0).argsort()

    for r, i in enumerate(lip_argsort.numpy()):
        lip_ranks.setdefault(i, []).append(r)
    
    for r, i in enumerate(pro_argsort.numpy()):
        pro_ranks.setdefault(i, []).append(r)

    for r, i in enumerate(metab_argsort.numpy()):
        metab_ranks.setdefault(i, []).append(r)

# %%
lip_mu_std = {k: (np.mean(v), np.std(v)) for k, v in lip_ranks.items()}
pro_mu_std = {k: (np.mean(v), np.std(v)) for k, v in pro_ranks.items()}
metab_mu_std = {k: (np.mean(v), np.std(v)) for k, v in metab_ranks.items()}

# %%
# sort lip_mu_std by the std
sorted(lip_mu_std.items(), key = lambda x: x[1][0], reverse = False)[:10]
# Out:
# [(3, (0.0, 0.0)),
#  (236, (1.58, 1.0215674231297707)),
#  (45, (3.98, 3.449579684541292)),
#  (35, (4.7, 3.9912404086950213)),
#  (152, (4.96, 3.3344264874187886)),
#  (211, (6.88, 2.329291737846507)),
#  (5, (7.6, 3.5888716889852725)),
#  (2, (7.96, 4.911048767829535)),
#  (201, (8.2, 2.5298221281347035)),
#  (4, (9.8, 3.3226495451672298))]

# %%
sorted(pro_mu_std.items(), key = lambda x: x[1][1], reverse = False)[:10]
# Out:
# [(3207, (3428.94, 0.23748684174075835)),
#  (2190, (0.32, 0.466476151587624)),
#  (1189, (0.68, 0.466476151587624)),
#  (1188, (2.66, 0.8151073548925932)),
#  (3208, (3427.48, 0.9641576634555159)),
#  (383, (3426.46, 1.2682271089990151)),
#  (3210, (3425.52, 1.4455448799674122)),
#  (3209, (3425.26, 1.5467385040788246)),
#  (2962, (3.26, 1.5976232346833217)),
#  (598, (3424.42, 1.7898603297464304))]

# %%
sorted(metab_mu_std.items(), key = lambda x: x[1][1], reverse = False)[:10]
# Out:
# [(51, (0.1, 0.4999999999999999)),
#  (43, (65.68, 0.705407683541936)),
#  (131, (55.96, 0.7472616676907761)),
#  (93, (69.96, 0.7472616676907762)),
#  (95, (67.34, 0.7644605941446557)),
#  (120, (54.52, 0.7807688518377254)),
#  (78, (71.84, 0.8089499366462674)),
#  (72, (58.08, 0.9130169768410661)),
#  (9, (68.58, 0.94)),
#  (53, (62.3, 0.9848857801796104))]

# %% [markdown]
# # Train on TCGA
#
# The TCGA dataset was processed as in (Lee and van der Schaar, 2021).  The features are kernel-PCA representations of the
# TCGA gene expression data.  The labels are the 1 year mortality status of the patients.

# %%
# load pre-processed tcga data
tcgadata = np.load('/Users/clab683/Documents/Data/tcga/multi_omics_1yr_mortality.npz')

# %%
rnaseq = torch.tensor(tcgadata['mRNAseq']).float()
methyl = torch.tensor(tcgadata['Methylation']).float()
mirna = torch.tensor(tcgadata['miRNAseq']).float()
rppa = torch.tensor(tcgadata['RPPA']).float()
labels = torch.tensor(tcgadata['label']).reshape(-1).long()

# sample train indices
train_inds = np.random.choice(len(rnaseq), size=int(len(rnaseq) * 0.7), replace=False)
valid_inds = np.setdiff1d(np.arange(len(rnaseq)), train_inds)
test_inds = np.random.choice(valid_inds, size=int(len(valid_inds) * 0.5), replace=False)
valid_inds = np.setdiff1d(valid_inds, test_inds)

# create train, valid, and test tensors
rnaseq_train = rnaseq[train_inds]
methyl_train = methyl[train_inds]
mirna_train = mirna[train_inds]
rppa_train = rppa[train_inds]
labels_train = labels[train_inds]

rnaseq_valid = rnaseq[valid_inds]
methyl_valid = methyl[valid_inds]
mirna_valid = mirna[valid_inds]
rppa_valid = rppa[valid_inds]
labels_valid = labels[valid_inds]

rnaseq_test = rnaseq[test_inds]
methyl_test = methyl[test_inds]
mirna_test = mirna[test_inds]
rppa_test = rppa[test_inds]
labels_test = labels[test_inds]

# dataloaders
train_dataset = torch.utils.data.TensorDataset(rnaseq_train, methyl_train, mirna_train, rppa_train, labels_train)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=32, shuffle=True)

valid_dataset = torch.utils.data.TensorDataset(rnaseq_valid, methyl_valid, mirna_valid, rppa_valid, labels_valid)
valid_loader = torch.utils.data.DataLoader(valid_dataset, batch_size=32, shuffle=True)

test_dataset = torch.utils.data.TensorDataset(rnaseq_test, methyl_test, mirna_test, rppa_test, labels_test)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=32, shuffle=True)

# %% [markdown]
# ### Build the model

# %%
# reload these modules with sys and importlib
import sys
import importlib

# import the modules
importlib.reload(sys.modules['models.fc_imv'])
from models.fc_imv import FC_Marginal, JointVAE

# three view-specific encoders with the appropriate input size:
marg_model = FC_Marginal(input_size=100, hidden_sizes=[256, 256], z_dim=32, prediction_dim=labels.unique().size()[0])

# joint model
joint_model = JointVAE(marginal_models=[copy.deepcopy(marg_model) for _ in range(4)], hidden_dim=128)

# define optimizer
optimizer = AdamW(joint_model.parameters(), lr=1e-4)

# %% [markdown]
# ## Training
#
# To facilitate training, we need to group samples into sub-batches with similar view-missing patterns.  In a single batch, there may be several sub-batches that we feed through the model one by one.  We accumulate the loss over these sub-batches and update the gradients one all sub-batches have been passed forward.
#
# The classes are heavily imbalanced, about 80% of patients survive to 1 year.  I use a class-balanced focal loss to address this issue.

# %%
# a function to build batches that group together batches of samples with the same view-missing patterns
def build_combo_batches(views):
    num_view_missing = []

    for view in views:
        na_views = torch.isnan(view).sum(axis = 1) > 0
        num_view_missing.append(na_views)

    which_na = torch.stack(num_view_missing, axis = 1)

    input_dict = {}
    gt_dict = {}

    comb = torch.unique(which_na, dim = 0)[0]
    which_na == comb.unsqueeze(0)

    for comb in torch.unique(which_na, dim = 0):
        inds = (which_na == comb.unsqueeze(0)).all(axis = 1)
        input_batch = [views[i][inds] if not comb[i] else None for i in range(len(views))]

        gt_dict[comb] = y[inds]
        input_dict[comb] = input_batch

    return input_dict, gt_dict

# %%
# handle class imbalance
alpha = torch.tensor([1/0.9391, 1/0.1609])
# focal constant 
gamma = 3

for epoch in range(40):
    accumulate_loss = []
    for idx, batch in enumerate(train_loader):
        x_rnaseq, x_methyl, x_mirna, x_clinical, y = batch
        views = x_rnaseq, x_methyl, x_mirna, x_clinical

        input_dict, gt_dict = build_combo_batches(views)

        loss = 0
        for comb, x in input_dict.items():
            y_gt = gt_dict[comb]
            yhat, poe_dist, yhats, dists = joint_model(x)
            # pass alpha and gamma to do focal loss
            tmp_loss = joint_model.loss(y_gt, yhat, poe_dist, yhats, dists, alpha = alpha, gamma = gamma)
            loss += tmp_loss

        loss.backward()
        torch.nn.utils.clip_grad_norm_(joint_model.parameters(), 2.0)
        optimizer.step()

        if idx % 50 == 0 and idx != 0:
            print(loss.item())

        accumulate_loss.append(loss.item())

    joint_model.eval()
    allpreds = []
    all_gt = []
    
    for batch in valid_loader:
        x_rnaseq, x_methyl, x_mirna, x_clinical, y = batch
        views = [x_rnaseq, x_methyl, x_mirna, x_clinical]

        num_view_missing = []

        input_dict, gt_dict = build_combo_batches(views)

        for comb, x in input_dict.items():
            y_gt = gt_dict[comb]
            with torch.inference_mode():
                yhat, poe_dist, yhats, dists = joint_model(x)
            preds = yhat.argmax(axis = 1) == y_gt
            allpreds.extend(preds.tolist())
            all_gt.extend(y_gt.tolist())

    pred_1 = np.array(allpreds)[np.array(all_gt) == 1]
    pred_0 = np.array(allpreds)[np.array(all_gt) == 0]
        
    joint_model.train()
    print(f"Average loss for epoch {epoch} is {np.mean(accumulate_loss)}, validation accuracy: 0: {np.mean(pred_0)}, 1: {np.mean(pred_1)}")

# %% [markdown]
# ## Evaluation on test set

# %%
joint_model.eval()
all_preds = []
all_gt = []
y_score = []

for batch in test_loader:
    x_rnaseq, x_methyl, x_mirna, x_clinical, y = batch
    views = [x_rnaseq, x_methyl, x_mirna, x_clinical]

    num_view_missing = []

    input_dict, gt_dict = build_combo_batches(views)

    for comb, x in input_dict.items():
        y_gt = gt_dict[comb]
        with torch.inference_mode():
            yhat, poe_dist, yhats, dists = joint_model(x)
        preds = yhat.argmax(axis = 1)
        all_preds.extend(preds.tolist())
        all_gt.extend(y_gt.tolist())
        y_score.extend(yhat[:, 1].tolist())

# %%
from sklearn.metrics import roc_curve, auc

fpr, tpr, _ = roc_curve(all_gt, y_score)
auc(fpr, tpr)
# Out:
# 0.8043450479233225

# %%
confusion_matrix(all_gt, all_preds)
# Out:
# array([[917,  22],
#        [133,  17]])

# %%
plt.plot(fpr, tpr)

# %%
# drop protein rows with all NA values 

# get indices with all nan values
# train_inds = (train_pro.isnull() == False).sum(axis = 1) > 0
# test_inds = (test_pro.isnull() == False).sum(axis = 1) > 0

# bad_inds = train_inds * test_inds

# # drop bad_inds
# train_pro = train_pro[bad_inds]
# test_pro = test_pro[bad_inds]

# # same for lipids and metabolites:
# train_inds = (train_lip.isnull() == False).sum(axis = 1) > 0
# test_inds = (test_lip.isnull() == False).sum(axis = 1) > 0

# bad_inds = train_inds * test_inds

# train_lip = train_lip[bad_inds]
# test_lip = test_lip[bad_inds]

# train_inds = (train_metab.isnull() == False).sum(axis = 1) > 0
# test_inds = (test_metab.isnull() == False).sum(axis = 1) > 0

# bad_inds = train_inds * test_inds

# train_metab = train_metab[bad_inds]
# test_metab = test_metab[bad_inds]
